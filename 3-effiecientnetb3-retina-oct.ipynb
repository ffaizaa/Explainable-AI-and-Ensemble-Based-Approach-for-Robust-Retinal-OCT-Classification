# %%
import os

# Check the contents of the input directory
print("Contents of /kaggle/input:")
print(os.listdir('/kaggle/input'))

# Use the correct path including the dataset name folder
dataset_folder = '/kaggle/input/oct-of-retina/RETINA OCT'
print(f"Contents of {dataset_folder}:")
print(os.listdir(dataset_folder))
# Out:
# Contents of /kaggle/input:
# ['oct-of-retina']
# Contents of /kaggle/input/oct-of-retina/RETINA OCT:
# ['valid', 'test', 'train']

# %% [markdown]
# # DATASET ANALYSIS

# %%
import os

def analyze_dataset(base_path):
    # Lists to store the splits we want to analyze
    splits = ['train', 'test', 'valid']
    
    for split in splits:
        split_path = os.path.join(base_path, split)
        
        # Check if the split directory exists
        if not os.path.exists(split_path):
            print(f"\nWarning: {split} directory not found!")
            continue
            
        # Get all classes (subdirectories) in this split
        classes = os.listdir(split_path)
        
        print(f"\n{split.upper()} SET:")
        print(f"Number of classes: {len(classes)}")
        print("Files per class:")
        
        # Count files in each class
        for class_name in classes:
            class_path = os.path.join(split_path, class_name)
            if os.path.isdir(class_path):  # Make sure it's a directory
                num_files = len(os.listdir(class_path))
                print(f"- {class_name}: {num_files} files")

# Path to the dataset
dataset_path = '/kaggle/input/oct-of-retina/RETINA OCT'

print("Dataset Analysis:")
print("=" * 50)
analyze_dataset(dataset_path)
# Out:
# Dataset Analysis:
# ==================================================
#
# TRAIN SET:
# Number of classes: 4
# Files per class:
# - DRUSEN: 4147 files
# - CNV: 4195 files
# - NORMAL: 4194 files
# - DME: 4179 files
#
# TEST SET:
# Number of classes: 4
# Files per class:
# - DRUSEN: 898 files
# - CNV: 900 files
# - NORMAL: 900 files
# - DME: 898 files
#
# VALID SET:
# Number of classes: 4
# Files per class:
# - DRUSEN: 895 files
# - CNV: 900 files
# - NORMAL: 900 files
# - DME: 899 files

# %%
# Define base path and subdirectories
dataset_path = "/kaggle/input/oct-of-retina/RETINA OCT"
train_dir = os.path.join(dataset_path, "train")
val_dir = os.path.join(dataset_path, "valid")
test_dir = os.path.join(dataset_path, "test")

print("Checking if directories exist:")
print(f"Train directory exists: {os.path.exists(train_dir)}")
print(f"Validation directory exists: {os.path.exists(val_dir)}")
print(f"Test directory exists: {os.path.exists(test_dir)}")

# Print example paths to verify structure
print("\nDirectory paths:")
print(f"Training: {train_dir}")
print(f"Validation: {val_dir}")
print(f"Testing: {test_dir}")
# Out:
# Checking if directories exist:
# Train directory exists: True
# Validation directory exists: True
# Test directory exists: True
#
# Directory paths:
# Training: /kaggle/input/oct-of-retina/RETINA OCT/train
# Validation: /kaggle/input/oct-of-retina/RETINA OCT/valid
# Testing: /kaggle/input/oct-of-retina/RETINA OCT/test

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Flatten, Dropout, GlobalAveragePooling2D
from tensorflow.keras.optimizers import Adam,SGD
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping, ModelCheckpoint
import os
import numpy as np

# %% [markdown]
# # Visualizing Raw images

# %%
import os
import matplotlib.pyplot as plt
import cv2
import random

# Function to visualize sample images from each class
def visualize_samples(data_dir, num_samples=5):
    
    classes = os.listdir(data_dir)
    classes = [cls for cls in classes if os.path.isdir(os.path.join(data_dir, cls))]  # Filter valid directories

    print(f"\nVisualizing samples from: {data_dir}")
    print(f"Classes: {classes}")
    
    plt.figure(figsize=(15, len(classes) * 3))
    
    for idx, class_name in enumerate(classes):
        class_dir = os.path.join(data_dir, class_name)
        image_files = os.listdir(class_dir)
        image_files = [f for f in image_files if f.lower().endswith(('png', 'jpg', 'jpeg'))]
        
        # Randomly select images
        selected_images = random.sample(image_files, min(len(image_files), num_samples))
        
        for j, img_file in enumerate(selected_images):
            img_path = os.path.join(class_dir, img_file)
            img = cv2.imread(img_path)  # Read as RGB
            img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)  # Convert BGR to RGB
            
            # Plot image
            plt.subplot(len(classes), num_samples, idx * num_samples + j + 1)
            plt.imshow(img)
            plt.title(f"{class_name}")
            plt.axis('off')
    
    plt.tight_layout()
    plt.show()

# Example usage:
train_dir = "/kaggle/input/oct-of-retina/RETINA OCT/train"  # Change this to the actual path
visualize_samples(train_dir)
# Out:
# Visualizing samples from: /kaggle/input/oct-of-retina/RETINA OCT/train
# Classes: ['DRUSEN', 'CNV', 'NORMAL', 'DME']

# %% [markdown]
# # Preprocessing and Augmentation

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=5,
    width_shift_range=0.1,
    height_shift_range=0.1,
    shear_range=0.1,
    zoom_range=0.1,
    horizontal_flip=True,
    brightness_range=[0.8, 1.2],
    fill_mode='nearest'
)
val_test_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
    '/kaggle/input/oct-of-retina/RETINA OCT/train',
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical',
    shuffle=True,
    color_mode='rgb'
)

val_generator = val_test_datagen.flow_from_directory(
    '/kaggle/input/oct-of-retina/RETINA OCT/valid',
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical',
    shuffle=False,
    color_mode='rgb'
)

test_generator = val_test_datagen.flow_from_directory(
    '/kaggle/input/oct-of-retina/RETINA OCT/test',
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical',
    shuffle=False,
    color_mode='rgb'
)
# Out:
# Found 16715 images belonging to 4 classes.
# Found 3594 images belonging to 4 classes.
# Found 3596 images belonging to 4 classes.

# %% [markdown]
# # Visualize the preprocessed image

# %%
def visualize_augmented_samples(generator, num_samples=5):
    # Get class names and indices from the generator
    class_indices = generator.class_indices
    class_names = sorted(class_indices.keys(), key=lambda x: class_indices[x])
    num_classes = len(class_names)
    
    # Initialize storage for samples
    samples = {i: [] for i in range(num_classes)}
    max_batches = 10  # Safety limit to prevent infinite loops
    
    # Collect samples from generator batches
    for _ in range(max_batches):
        images, labels = next(generator)
        for img, label in zip(images, labels):
            class_idx = label.argmax()
            if len(samples[class_idx]) < num_samples:
                samples[class_idx].append(img)
        
        # Check if we've collected enough samples for all classes
        if all(len(v) >= num_samples for v in samples.values()):
            break
    
    # Create plot
    plt.figure(figsize=(15, num_classes * 3))
    
    for idx, class_name in enumerate(class_names):
        class_imgs = samples[idx][:num_samples]  # Get up to num_samples
        
        for j, img in enumerate(class_imgs):
            # Calculate position in grid
            position = idx * num_samples + j + 1
            plt.subplot(num_classes, num_samples, position)
            
            # Display image (assuming generator outputs [0,1] float values)
            plt.imshow(img)
            plt.title(f"{class_name}")
            plt.axis('off')

    plt.tight_layout()
    plt.show()

# Example usage
visualize_augmented_samples(train_generator)

# %% [markdown]
# # EfficientNetB3 model

# %%
import tensorflow as tf
from tensorflow.keras.applications import EfficientNetB3
from tensorflow.keras.applications.efficientnet import preprocess_input as efficientnet_preprocess
from tensorflow.keras.layers import Input, Lambda, GlobalAveragePooling2D, Dense, Dropout, BatchNormalization, ReLU
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

def create_model_EfficientNetB3(input_shape, num_classes, fine_tune_at=-20, dropout_rate=0.5, l2_lambda=1e-4, learning_rate=0.01):
    inputs = Input(shape=input_shape)
    x = Lambda(lambda x: efficientnet_preprocess(x * 255.0))(inputs)
    base_model = EfficientNetB3(weights='imagenet', include_top=False, input_tensor=x, input_shape=input_shape)
    if fine_tune_at is not None:
        if fine_tune_at < 0:
            fine_tune_at = len(base_model.layers) + fine_tune_at
        base_model.trainable = True
        for layer in base_model.layers[:fine_tune_at]:
            layer.trainable = False
    else:
        base_model.trainable = False
    x = GlobalAveragePooling2D()(base_model.output)
    x = Dense(512, kernel_regularizer=l2(l2_lambda))(x)
    x = BatchNormalization()(x)
    x = ReLU()(x)
    x = Dropout(dropout_rate)(x)
    x = Dense(256, kernel_regularizer=l2(l2_lambda))(x)
    x = BatchNormalization()(x)
    x = ReLU()(x)
    x = Dropout(dropout_rate * 0.7)(x)
    predictions = Dense(num_classes, activation='softmax')(x)
    model = Model(inputs=inputs, outputs=predictions)
    model.compile(optimizer=SGD(learning_rate=learning_rate, momentum=0.9, nesterov=True),
                  loss='categorical_crossentropy',
                  metrics=['accuracy', tf.keras.metrics.AUC()])
    return model

# %%
# Instantiate the model
model1 = create_model_EfficientNetB3(input_shape=(224, 224, 3), num_classes=4)


from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau


# Define callbacks
callbacks = [
    EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True),
    ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3),
]

model1.summary()
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb3_notop.h5
# 43941136/43941136 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)  │ (None, 224, 224, 3)    │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lambda (Lambda)           │ (None, 224, 224, 3)    │              0 │ input_layer[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ rescaling (Rescaling)     │ (None, 224, 224, 3)    │              0 │ lambda[0][0]           │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ normalization             │ (None, 224, 224, 3)    │              7 │ rescaling[0][0]        │
# │ (Normalization)           │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ rescaling_1 (Rescaling)   │ (None, 224, 224, 3)    │              0 │ normalization[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ stem_conv_pad             │ (None, 225, 225, 3)    │              0 │ rescaling_1[0][0]      │
# │ (ZeroPadding2D)           │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ stem_conv (Conv2D)        │ (None, 112, 112, 40)   │          1,080 │ stem_conv_pad[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ stem_bn                   │ (None, 112, 112, 40)   │            160 │ stem_conv[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ stem_activation           │ (None, 112, 112, 40)   │              0 │ stem_bn[0][0]          │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block1a_dwconv            │ (None, 112, 112, 40)   │            360 │ stem_activation[0][0]  │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block1a_bn                │ (None, 112, 112, 40)   │            160 │ block1a_dwconv[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block1a_activation        │ (None, 112, 112, 40)   │              0 │ block1a_bn[0][0]       │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block1a_se_squeeze        │ (None, 40)             │              0 │ block1a_activation[0]… │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block1a_se_reshape        │ (None, 1, 1, 40)       │              0 │ block1a_se_squeeze[0]… │
# │ (Reshape)                 │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block1a_se_reduce         │ (None, 1, 1, 10)       │            410 │ block1a_se_reshape[0]… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block1a_se_expand         │ (None, 1, 1, 40)       │            440 │ block1a_se_reduce[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block1a_se_excite         │ (None, 112, 112, 40)   │              0 │ block1a_activation[0]… │
# │ (Multiply)                │                        │                │ block1a_se_expand[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block1a_project_conv      │ (None, 112, 112, 24)   │            960 │ block1a_se_excite[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block1a_project_bn        │ (None, 112, 112, 24)   │             96 │ block1a_project_conv[… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block1b_dwconv            │ (None, 112, 112, 24)   │            216 │ block1a_project_bn[0]… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block1b_bn                │ (None, 112, 112, 24)   │             96 │ block1b_dwconv[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block1b_activation        │ (None, 112, 112, 24)   │              0 │ block1b_bn[0][0]       │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block1b_se_squeeze        │ (None, 24)             │              0 │ block1b_activation[0]… │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block1b_se_reshape        │ (None, 1, 1, 24)       │              0 │ block1b_se_squeeze[0]… │
# │ (Reshape)                 │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block1b_se_reduce         │ (None, 1, 1, 6)        │            150 │ block1b_se_reshape[0]… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block1b_se_expand         │ (None, 1, 1, 24)       │            168 │ block1b_se_reduce[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block1b_se_excite         │ (None, 112, 112, 24)   │              0 │ block1b_activation[0]… │
# │ (Multiply)                │                        │                │ block1b_se_expand[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block1b_project_conv      │ (None, 112, 112, 24)   │            576 │ block1b_se_excite[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block1b_project_bn        │ (None, 112, 112, 24)   │             96 │ block1b_project_conv[… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block1b_drop (Dropout)    │ (None, 112, 112, 24)   │              0 │ block1b_project_bn[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block1b_add (Add)         │ (None, 112, 112, 24)   │              0 │ block1b_drop[0][0],    │
# │                           │                        │                │ block1a_project_bn[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2a_expand_conv       │ (None, 112, 112, 144)  │          3,456 │ block1b_add[0][0]      │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2a_expand_bn         │ (None, 112, 112, 144)  │            576 │ block2a_expand_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2a_expand_activation │ (None, 112, 112, 144)  │              0 │ block2a_expand_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2a_dwconv_pad        │ (None, 113, 113, 144)  │              0 │ block2a_expand_activa… │
# │ (ZeroPadding2D)           │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2a_dwconv            │ (None, 56, 56, 144)    │          1,296 │ block2a_dwconv_pad[0]… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2a_bn                │ (None, 56, 56, 144)    │            576 │ block2a_dwconv[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2a_activation        │ (None, 56, 56, 144)    │              0 │ block2a_bn[0][0]       │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2a_se_squeeze        │ (None, 144)            │              0 │ block2a_activation[0]… │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2a_se_reshape        │ (None, 1, 1, 144)      │              0 │ block2a_se_squeeze[0]… │
# │ (Reshape)                 │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2a_se_reduce         │ (None, 1, 1, 6)        │            870 │ block2a_se_reshape[0]… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2a_se_expand         │ (None, 1, 1, 144)      │          1,008 │ block2a_se_reduce[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2a_se_excite         │ (None, 56, 56, 144)    │              0 │ block2a_activation[0]… │
# │ (Multiply)                │                        │                │ block2a_se_expand[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2a_project_conv      │ (None, 56, 56, 32)     │          4,608 │ block2a_se_excite[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2a_project_bn        │ (None, 56, 56, 32)     │            128 │ block2a_project_conv[… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2b_expand_conv       │ (None, 56, 56, 192)    │          6,144 │ block2a_project_bn[0]… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2b_expand_bn         │ (None, 56, 56, 192)    │            768 │ block2b_expand_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2b_expand_activation │ (None, 56, 56, 192)    │              0 │ block2b_expand_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2b_dwconv            │ (None, 56, 56, 192)    │          1,728 │ block2b_expand_activa… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2b_bn                │ (None, 56, 56, 192)    │            768 │ block2b_dwconv[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2b_activation        │ (None, 56, 56, 192)    │              0 │ block2b_bn[0][0]       │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2b_se_squeeze        │ (None, 192)            │              0 │ block2b_activation[0]… │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2b_se_reshape        │ (None, 1, 1, 192)      │              0 │ block2b_se_squeeze[0]… │
# │ (Reshape)                 │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2b_se_reduce         │ (None, 1, 1, 8)        │          1,544 │ block2b_se_reshape[0]… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2b_se_expand         │ (None, 1, 1, 192)      │          1,728 │ block2b_se_reduce[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2b_se_excite         │ (None, 56, 56, 192)    │              0 │ block2b_activation[0]… │
# │ (Multiply)                │                        │                │ block2b_se_expand[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2b_project_conv      │ (None, 56, 56, 32)     │          6,144 │ block2b_se_excite[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2b_project_bn        │ (None, 56, 56, 32)     │            128 │ block2b_project_conv[… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2b_drop (Dropout)    │ (None, 56, 56, 32)     │              0 │ block2b_project_bn[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2b_add (Add)         │ (None, 56, 56, 32)     │              0 │ block2b_drop[0][0],    │
# │                           │                        │                │ block2a_project_bn[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2c_expand_conv       │ (None, 56, 56, 192)    │          6,144 │ block2b_add[0][0]      │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2c_expand_bn         │ (None, 56, 56, 192)    │            768 │ block2c_expand_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2c_expand_activation │ (None, 56, 56, 192)    │              0 │ block2c_expand_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2c_dwconv            │ (None, 56, 56, 192)    │          1,728 │ block2c_expand_activa… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2c_bn                │ (None, 56, 56, 192)    │            768 │ block2c_dwconv[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2c_activation        │ (None, 56, 56, 192)    │              0 │ block2c_bn[0][0]       │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2c_se_squeeze        │ (None, 192)            │              0 │ block2c_activation[0]… │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2c_se_reshape        │ (None, 1, 1, 192)      │              0 │ block2c_se_squeeze[0]… │
# │ (Reshape)                 │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2c_se_reduce         │ (None, 1, 1, 8)        │          1,544 │ block2c_se_reshape[0]… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2c_se_expand         │ (None, 1, 1, 192)      │          1,728 │ block2c_se_reduce[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2c_se_excite         │ (None, 56, 56, 192)    │              0 │ block2c_activation[0]… │
# │ (Multiply)                │                        │                │ block2c_se_expand[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2c_project_conv      │ (None, 56, 56, 32)     │          6,144 │ block2c_se_excite[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2c_project_bn        │ (None, 56, 56, 32)     │            128 │ block2c_project_conv[… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2c_drop (Dropout)    │ (None, 56, 56, 32)     │              0 │ block2c_project_bn[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2c_add (Add)         │ (None, 56, 56, 32)     │              0 │ block2c_drop[0][0],    │
# │                           │                        │                │ block2b_add[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3a_expand_conv       │ (None, 56, 56, 192)    │          6,144 │ block2c_add[0][0]      │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3a_expand_bn         │ (None, 56, 56, 192)    │            768 │ block3a_expand_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3a_expand_activation │ (None, 56, 56, 192)    │              0 │ block3a_expand_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3a_dwconv_pad        │ (None, 59, 59, 192)    │              0 │ block3a_expand_activa… │
# │ (ZeroPadding2D)           │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3a_dwconv            │ (None, 28, 28, 192)    │          4,800 │ block3a_dwconv_pad[0]… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3a_bn                │ (None, 28, 28, 192)    │            768 │ block3a_dwconv[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3a_activation        │ (None, 28, 28, 192)    │              0 │ block3a_bn[0][0]       │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3a_se_squeeze        │ (None, 192)            │              0 │ block3a_activation[0]… │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3a_se_reshape        │ (None, 1, 1, 192)      │              0 │ block3a_se_squeeze[0]… │
# │ (Reshape)                 │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3a_se_reduce         │ (None, 1, 1, 8)        │          1,544 │ block3a_se_reshape[0]… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3a_se_expand         │ (None, 1, 1, 192)      │          1,728 │ block3a_se_reduce[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3a_se_excite         │ (None, 28, 28, 192)    │              0 │ block3a_activation[0]… │
# │ (Multiply)                │                        │                │ block3a_se_expand[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3a_project_conv      │ (None, 28, 28, 48)     │          9,216 │ block3a_se_excite[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3a_project_bn        │ (None, 28, 28, 48)     │            192 │ block3a_project_conv[… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3b_expand_conv       │ (None, 28, 28, 288)    │         13,824 │ block3a_project_bn[0]… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3b_expand_bn         │ (None, 28, 28, 288)    │          1,152 │ block3b_expand_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3b_expand_activation │ (None, 28, 28, 288)    │              0 │ block3b_expand_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3b_dwconv            │ (None, 28, 28, 288)    │          7,200 │ block3b_expand_activa… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3b_bn                │ (None, 28, 28, 288)    │          1,152 │ block3b_dwconv[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3b_activation        │ (None, 28, 28, 288)    │              0 │ block3b_bn[0][0]       │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3b_se_squeeze        │ (None, 288)            │              0 │ block3b_activation[0]… │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3b_se_reshape        │ (None, 1, 1, 288)      │              0 │ block3b_se_squeeze[0]… │
# │ (Reshape)                 │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3b_se_reduce         │ (None, 1, 1, 12)       │          3,468 │ block3b_se_reshape[0]… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3b_se_expand         │ (None, 1, 1, 288)      │          3,744 │ block3b_se_reduce[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3b_se_excite         │ (None, 28, 28, 288)    │              0 │ block3b_activation[0]… │
# │ (Multiply)                │                        │                │ block3b_se_expand[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3b_project_conv      │ (None, 28, 28, 48)     │         13,824 │ block3b_se_excite[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3b_project_bn        │ (None, 28, 28, 48)     │            192 │ block3b_project_conv[… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3b_drop (Dropout)    │ (None, 28, 28, 48)     │              0 │ block3b_project_bn[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3b_add (Add)         │ (None, 28, 28, 48)     │              0 │ block3b_drop[0][0],    │
# │                           │                        │                │ block3a_project_bn[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3c_expand_conv       │ (None, 28, 28, 288)    │         13,824 │ block3b_add[0][0]      │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3c_expand_bn         │ (None, 28, 28, 288)    │          1,152 │ block3c_expand_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3c_expand_activation │ (None, 28, 28, 288)    │              0 │ block3c_expand_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3c_dwconv            │ (None, 28, 28, 288)    │          7,200 │ block3c_expand_activa… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3c_bn                │ (None, 28, 28, 288)    │          1,152 │ block3c_dwconv[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3c_activation        │ (None, 28, 28, 288)    │              0 │ block3c_bn[0][0]       │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3c_se_squeeze        │ (None, 288)            │              0 │ block3c_activation[0]… │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3c_se_reshape        │ (None, 1, 1, 288)      │              0 │ block3c_se_squeeze[0]… │
# │ (Reshape)                 │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3c_se_reduce         │ (None, 1, 1, 12)       │          3,468 │ block3c_se_reshape[0]… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3c_se_expand         │ (None, 1, 1, 288)      │          3,744 │ block3c_se_reduce[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3c_se_excite         │ (None, 28, 28, 288)    │              0 │ block3c_activation[0]… │
# │ (Multiply)                │                        │                │ block3c_se_expand[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3c_project_conv      │ (None, 28, 28, 48)     │         13,824 │ block3c_se_excite[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3c_project_bn        │ (None, 28, 28, 48)     │            192 │ block3c_project_conv[… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3c_drop (Dropout)    │ (None, 28, 28, 48)     │              0 │ block3c_project_bn[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3c_add (Add)         │ (None, 28, 28, 48)     │              0 │ block3c_drop[0][0],    │
# │                           │                        │                │ block3b_add[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4a_expand_conv       │ (None, 28, 28, 288)    │         13,824 │ block3c_add[0][0]      │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4a_expand_bn         │ (None, 28, 28, 288)    │          1,152 │ block4a_expand_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4a_expand_activation │ (None, 28, 28, 288)    │              0 │ block4a_expand_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4a_dwconv_pad        │ (None, 29, 29, 288)    │              0 │ block4a_expand_activa… │
# │ (ZeroPadding2D)           │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4a_dwconv            │ (None, 14, 14, 288)    │          2,592 │ block4a_dwconv_pad[0]… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4a_bn                │ (None, 14, 14, 288)    │          1,152 │ block4a_dwconv[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4a_activation        │ (None, 14, 14, 288)    │              0 │ block4a_bn[0][0]       │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4a_se_squeeze        │ (None, 288)            │              0 │ block4a_activation[0]… │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4a_se_reshape        │ (None, 1, 1, 288)      │              0 │ block4a_se_squeeze[0]… │
# │ (Reshape)                 │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4a_se_reduce         │ (None, 1, 1, 12)       │          3,468 │ block4a_se_reshape[0]… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4a_se_expand         │ (None, 1, 1, 288)      │          3,744 │ block4a_se_reduce[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4a_se_excite         │ (None, 14, 14, 288)    │              0 │ block4a_activation[0]… │
# │ (Multiply)                │                        │                │ block4a_se_expand[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4a_project_conv      │ (None, 14, 14, 96)     │         27,648 │ block4a_se_excite[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4a_project_bn        │ (None, 14, 14, 96)     │            384 │ block4a_project_conv[… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4b_expand_conv       │ (None, 14, 14, 576)    │         55,296 │ block4a_project_bn[0]… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4b_expand_bn         │ (None, 14, 14, 576)    │          2,304 │ block4b_expand_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4b_expand_activation │ (None, 14, 14, 576)    │              0 │ block4b_expand_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4b_dwconv            │ (None, 14, 14, 576)    │          5,184 │ block4b_expand_activa… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4b_bn                │ (None, 14, 14, 576)    │          2,304 │ block4b_dwconv[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4b_activation        │ (None, 14, 14, 576)    │              0 │ block4b_bn[0][0]       │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4b_se_squeeze        │ (None, 576)            │              0 │ block4b_activation[0]… │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4b_se_reshape        │ (None, 1, 1, 576)      │              0 │ block4b_se_squeeze[0]… │
# │ (Reshape)                 │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4b_se_reduce         │ (None, 1, 1, 24)       │         13,848 │ block4b_se_reshape[0]… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4b_se_expand         │ (None, 1, 1, 576)      │         14,400 │ block4b_se_reduce[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4b_se_excite         │ (None, 14, 14, 576)    │              0 │ block4b_activation[0]… │
# │ (Multiply)                │                        │                │ block4b_se_expand[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4b_project_conv      │ (None, 14, 14, 96)     │         55,296 │ block4b_se_excite[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4b_project_bn        │ (None, 14, 14, 96)     │            384 │ block4b_project_conv[… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4b_drop (Dropout)    │ (None, 14, 14, 96)     │              0 │ block4b_project_bn[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4b_add (Add)         │ (None, 14, 14, 96)     │              0 │ block4b_drop[0][0],    │
# │                           │                        │                │ block4a_project_bn[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4c_expand_conv       │ (None, 14, 14, 576)    │         55,296 │ block4b_add[0][0]      │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4c_expand_bn         │ (None, 14, 14, 576)    │          2,304 │ block4c_expand_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4c_expand_activation │ (None, 14, 14, 576)    │              0 │ block4c_expand_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4c_dwconv            │ (None, 14, 14, 576)    │          5,184 │ block4c_expand_activa… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4c_bn                │ (None, 14, 14, 576)    │          2,304 │ block4c_dwconv[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4c_activation        │ (None, 14, 14, 576)    │              0 │ block4c_bn[0][0]       │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4c_se_squeeze        │ (None, 576)            │              0 │ block4c_activation[0]… │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4c_se_reshape        │ (None, 1, 1, 576)      │              0 │ block4c_se_squeeze[0]… │
# │ (Reshape)                 │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4c_se_reduce         │ (None, 1, 1, 24)       │         13,848 │ block4c_se_reshape[0]… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4c_se_expand         │ (None, 1, 1, 576)      │         14,400 │ block4c_se_reduce[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4c_se_excite         │ (None, 14, 14, 576)    │              0 │ block4c_activation[0]… │
# │ (Multiply)                │                        │                │ block4c_se_expand[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4c_project_conv      │ (None, 14, 14, 96)     │         55,296 │ block4c_se_excite[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4c_project_bn        │ (None, 14, 14, 96)     │            384 │ block4c_project_conv[… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4c_drop (Dropout)    │ (None, 14, 14, 96)     │              0 │ block4c_project_bn[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4c_add (Add)         │ (None, 14, 14, 96)     │              0 │ block4c_drop[0][0],    │
# │                           │                        │                │ block4b_add[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4d_expand_conv       │ (None, 14, 14, 576)    │         55,296 │ block4c_add[0][0]      │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4d_expand_bn         │ (None, 14, 14, 576)    │          2,304 │ block4d_expand_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4d_expand_activation │ (None, 14, 14, 576)    │              0 │ block4d_expand_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4d_dwconv            │ (None, 14, 14, 576)    │          5,184 │ block4d_expand_activa… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4d_bn                │ (None, 14, 14, 576)    │          2,304 │ block4d_dwconv[0][0]   │
# ...
# │ block6e_drop (Dropout)    │ (None, 7, 7, 232)      │              0 │ block6e_project_bn[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6e_add (Add)         │ (None, 7, 7, 232)      │              0 │ block6e_drop[0][0],    │
# │                           │                        │                │ block6d_add[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6f_expand_conv       │ (None, 7, 7, 1392)     │        322,944 │ block6e_add[0][0]      │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6f_expand_bn         │ (None, 7, 7, 1392)     │          5,568 │ block6f_expand_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6f_expand_activation │ (None, 7, 7, 1392)     │              0 │ block6f_expand_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6f_dwconv            │ (None, 7, 7, 1392)     │         34,800 │ block6f_expand_activa… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6f_bn                │ (None, 7, 7, 1392)     │          5,568 │ block6f_dwconv[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6f_activation        │ (None, 7, 7, 1392)     │              0 │ block6f_bn[0][0]       │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6f_se_squeeze        │ (None, 1392)           │              0 │ block6f_activation[0]… │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6f_se_reshape        │ (None, 1, 1, 1392)     │              0 │ block6f_se_squeeze[0]… │
# │ (Reshape)                 │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6f_se_reduce         │ (None, 1, 1, 58)       │         80,794 │ block6f_se_reshape[0]… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6f_se_expand         │ (None, 1, 1, 1392)     │         82,128 │ block6f_se_reduce[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6f_se_excite         │ (None, 7, 7, 1392)     │              0 │ block6f_activation[0]… │
# │ (Multiply)                │                        │                │ block6f_se_expand[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6f_project_conv      │ (None, 7, 7, 232)      │        322,944 │ block6f_se_excite[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6f_project_bn        │ (None, 7, 7, 232)      │            928 │ block6f_project_conv[… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6f_drop (Dropout)    │ (None, 7, 7, 232)      │              0 │ block6f_project_bn[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6f_add (Add)         │ (None, 7, 7, 232)      │              0 │ block6f_drop[0][0],    │
# │                           │                        │                │ block6e_add[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block7a_expand_conv       │ (None, 7, 7, 1392)     │        322,944 │ block6f_add[0][0]      │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block7a_expand_bn         │ (None, 7, 7, 1392)     │          5,568 │ block7a_expand_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block7a_expand_activation │ (None, 7, 7, 1392)     │              0 │ block7a_expand_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block7a_dwconv            │ (None, 7, 7, 1392)     │         12,528 │ block7a_expand_activa… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block7a_bn                │ (None, 7, 7, 1392)     │          5,568 │ block7a_dwconv[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block7a_activation        │ (None, 7, 7, 1392)     │              0 │ block7a_bn[0][0]       │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block7a_se_squeeze        │ (None, 1392)           │              0 │ block7a_activation[0]… │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block7a_se_reshape        │ (None, 1, 1, 1392)     │              0 │ block7a_se_squeeze[0]… │
# │ (Reshape)                 │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block7a_se_reduce         │ (None, 1, 1, 58)       │         80,794 │ block7a_se_reshape[0]… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block7a_se_expand         │ (None, 1, 1, 1392)     │         82,128 │ block7a_se_reduce[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block7a_se_excite         │ (None, 7, 7, 1392)     │              0 │ block7a_activation[0]… │
# │ (Multiply)                │                        │                │ block7a_se_expand[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block7a_project_conv      │ (None, 7, 7, 384)      │        534,528 │ block7a_se_excite[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block7a_project_bn        │ (None, 7, 7, 384)      │          1,536 │ block7a_project_conv[… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block7b_expand_conv       │ (None, 7, 7, 2304)     │        884,736 │ block7a_project_bn[0]… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block7b_expand_bn         │ (None, 7, 7, 2304)     │          9,216 │ block7b_expand_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block7b_expand_activation │ (None, 7, 7, 2304)     │              0 │ block7b_expand_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block7b_dwconv            │ (None, 7, 7, 2304)     │         20,736 │ block7b_expand_activa… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block7b_bn                │ (None, 7, 7, 2304)     │          9,216 │ block7b_dwconv[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block7b_activation        │ (None, 7, 7, 2304)     │              0 │ block7b_bn[0][0]       │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block7b_se_squeeze        │ (None, 2304)           │              0 │ block7b_activation[0]… │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block7b_se_reshape        │ (None, 1, 1, 2304)     │              0 │ block7b_se_squeeze[0]… │
# │ (Reshape)                 │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block7b_se_reduce         │ (None, 1, 1, 96)       │        221,280 │ block7b_se_reshape[0]… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block7b_se_expand         │ (None, 1, 1, 2304)     │        223,488 │ block7b_se_reduce[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block7b_se_excite         │ (None, 7, 7, 2304)     │              0 │ block7b_activation[0]… │
# │ (Multiply)                │                        │                │ block7b_se_expand[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block7b_project_conv      │ (None, 7, 7, 384)      │        884,736 │ block7b_se_excite[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block7b_project_bn        │ (None, 7, 7, 384)      │          1,536 │ block7b_project_conv[… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block7b_drop (Dropout)    │ (None, 7, 7, 384)      │              0 │ block7b_project_bn[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block7b_add (Add)         │ (None, 7, 7, 384)      │              0 │ block7b_drop[0][0],    │
# │                           │                        │                │ block7a_project_bn[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ top_conv (Conv2D)         │ (None, 7, 7, 1536)     │        589,824 │ block7b_add[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ top_bn                    │ (None, 7, 7, 1536)     │          6,144 │ top_conv[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ top_activation            │ (None, 7, 7, 1536)     │              0 │ top_bn[0][0]           │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ global_average_pooling2d  │ (None, 1536)           │              0 │ top_activation[0][0]   │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense (Dense)             │ (None, 512)            │        786,944 │ global_average_poolin… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization       │ (None, 512)            │          2,048 │ dense[0][0]            │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu (ReLU)              │ (None, 512)            │              0 │ batch_normalization[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout (Dropout)         │ (None, 512)            │              0 │ re_lu[0][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_1 (Dense)           │ (None, 256)            │        131,328 │ dropout[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_1     │ (None, 256)            │          1,024 │ dense_1[0][0]          │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_1 (ReLU)            │ (None, 256)            │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_1 (Dropout)       │ (None, 256)            │              0 │ re_lu_1[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_2 (Dense)           │ (None, 4)              │          1,028 │ dropout_1[0][0]        │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 11,705,907 (44.65 MB)
#  Trainable params: 4,293,988 (16.38 MB)
#  Non-trainable params: 7,411,919 (28.27 MB)

# %% [markdown]
# # Model Training

# %%
history = model1.fit(
    train_generator,  
    validation_data=val_generator,
    epochs=30,
    callbacks=callbacks,
    verbose=1
)

model1.save('RETINAxEfficientNetB3.keras')
# Out:
# Epoch 1/30
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 523/523 ━━━━━━━━━━━━━━━━━━━━ 380s 641ms/step - accuracy: 0.6846 - auc: 0.8860 - loss: 0.9165 - val_accuracy: 0.8422 - val_auc: 0.9710 - val_loss: 0.5231 - learning_rate: 0.0100
# Epoch 2/30
# 523/523 ━━━━━━━━━━━━━━━━━━━━ 247s 467ms/step - accuracy: 0.8200 - auc: 0.9601 - loss: 0.5876 - val_accuracy: 0.8497 - val_auc: 0.9719 - val_loss: 0.5075 - learning_rate: 0.0100
# Epoch 3/30
# 523/523 ━━━━━━━━━━━━━━━━━━━━ 242s 458ms/step - accuracy: 0.8440 - auc: 0.9676 - loss: 0.5353 - val_accuracy: 0.8639 - val_auc: 0.9752 - val_loss: 0.4790 - learning_rate: 0.0100
# Epoch 4/30
# 523/523 ━━━━━━━━━━━━━━━━━━━━ 243s 459ms/step - accuracy: 0.8601 - auc: 0.9713 - loss: 0.5045 - val_accuracy: 0.8740 - val_auc: 0.9792 - val_loss: 0.4460 - learning_rate: 0.0100
# Epoch 5/30
# 523/523 ━━━━━━━━━━━━━━━━━━━━ 244s 461ms/step - accuracy: 0.8613 - auc: 0.9748 - loss: 0.4777 - val_accuracy: 0.8879 - val_auc: 0.9824 - val_loss: 0.4139 - learning_rate: 0.0100
# Epoch 6/30
# 523/523 ━━━━━━━━━━━━━━━━━━━━ 244s 461ms/step - accuracy: 0.8705 - auc: 0.9772 - loss: 0.4562 - val_accuracy: 0.8765 - val_auc: 0.9804 - val_loss: 0.4273 - learning_rate: 0.0100
# Epoch 7/30
# 523/523 ━━━━━━━━━━━━━━━━━━━━ 244s 461ms/step - accuracy: 0.8741 - auc: 0.9792 - loss: 0.4386 - val_accuracy: 0.8756 - val_auc: 0.9767 - val_loss: 0.4577 - learning_rate: 0.0100
# Epoch 8/30
# 523/523 ━━━━━━━━━━━━━━━━━━━━ 244s 461ms/step - accuracy: 0.8846 - auc: 0.9812 - loss: 0.4173 - val_accuracy: 0.8798 - val_auc: 0.9802 - val_loss: 0.4302 - learning_rate: 0.0100
# Epoch 9/30
# 523/523 ━━━━━━━━━━━━━━━━━━━━ 243s 459ms/step - accuracy: 0.8897 - auc: 0.9825 - loss: 0.4069 - val_accuracy: 0.9065 - val_auc: 0.9865 - val_loss: 0.3657 - learning_rate: 0.0050
# Epoch 10/30
# 523/523 ━━━━━━━━━━━━━━━━━━━━ 244s 461ms/step - accuracy: 0.9042 - auc: 0.9849 - loss: 0.3781 - val_accuracy: 0.9026 - val_auc: 0.9849 - val_loss: 0.3794 - learning_rate: 0.0050
# Epoch 11/30
# 523/523 ━━━━━━━━━━━━━━━━━━━━ 243s 459ms/step - accuracy: 0.9013 - auc: 0.9863 - loss: 0.3650 - val_accuracy: 0.8982 - val_auc: 0.9843 - val_loss: 0.3843 - learning_rate: 0.0050
# Epoch 12/30
# 523/523 ━━━━━━━━━━━━━━━━━━━━ 242s 456ms/step - accuracy: 0.9080 - auc: 0.9877 - loss: 0.3504 - val_accuracy: 0.8893 - val_auc: 0.9825 - val_loss: 0.4025 - learning_rate: 0.0050
# Epoch 13/30
# 523/523 ━━━━━━━━━━━━━━━━━━━━ 243s 459ms/step - accuracy: 0.9095 - auc: 0.9879 - loss: 0.3478 - val_accuracy: 0.9046 - val_auc: 0.9847 - val_loss: 0.3757 - learning_rate: 0.0025
# Epoch 14/30
# 523/523 ━━━━━━━━━━━━━━━━━━━━ 243s 458ms/step - accuracy: 0.9096 - auc: 0.9877 - loss: 0.3487 - val_accuracy: 0.9096 - val_auc: 0.9856 - val_loss: 0.3649 - learning_rate: 0.0025
# Epoch 15/30
# 523/523 ━━━━━━━━━━━━━━━━━━━━ 243s 458ms/step - accuracy: 0.9131 - auc: 0.9888 - loss: 0.3338 - val_accuracy: 0.9068 - val_auc: 0.9862 - val_loss: 0.3634 - learning_rate: 0.0025
# Epoch 16/30
# 523/523 ━━━━━━━━━━━━━━━━━━━━ 242s 457ms/step - accuracy: 0.9191 - auc: 0.9897 - loss: 0.3244 - val_accuracy: 0.9085 - val_auc: 0.9860 - val_loss: 0.3607 - learning_rate: 0.0025
# Epoch 17/30
# 523/523 ━━━━━━━━━━━━━━━━━━━━ 240s 453ms/step - accuracy: 0.9165 - auc: 0.9896 - loss: 0.3258 - val_accuracy: 0.9018 - val_auc: 0.9850 - val_loss: 0.3755 - learning_rate: 0.0025
# Epoch 18/30
# 523/523 ━━━━━━━━━━━━━━━━━━━━ 240s 454ms/step - accuracy: 0.9193 - auc: 0.9900 - loss: 0.3157 - val_accuracy: 0.9071 - val_auc: 0.9857 - val_loss: 0.3670 - learning_rate: 0.0025
# Epoch 19/30
# 523/523 ━━━━━━━━━━━━━━━━━━━━ 244s 461ms/step - accuracy: 0.9204 - auc: 0.9905 - loss: 0.3136 - val_accuracy: 0.9140 - val_auc: 0.9870 - val_loss: 0.3490 - learning_rate: 0.0025
# Epoch 20/30
# 523/523 ━━━━━━━━━━━━━━━━━━━━ 240s 454ms/step - accuracy: 0.9206 - auc: 0.9897 - loss: 0.3200 - val_accuracy: 0.9118 - val_auc: 0.9862 - val_loss: 0.3579 - learning_rate: 0.0025
# Epoch 21/30
# 523/523 ━━━━━━━━━━━━━━━━━━━━ 243s 459ms/step - accuracy: 0.9241 - auc: 0.9906 - loss: 0.3070 - val_accuracy: 0.9007 - val_auc: 0.9850 - val_loss: 0.3782 - learning_rate: 0.0025
# Epoch 22/30
# 523/523 ━━━━━━━━━━━━━━━━━━━━ 242s 456ms/step - accuracy: 0.9260 - auc: 0.9913 - loss: 0.2999 - val_accuracy: 0.9035 - val_auc: 0.9853 - val_loss: 0.3739 - learning_rate: 0.0025
# Epoch 23/30
# 523/523 ━━━━━━━━━━━━━━━━━━━━ 242s 457ms/step - accuracy: 0.9240 - auc: 0.9914 - loss: 0.3010 - val_accuracy: 0.9143 - val_auc: 0.9869 - val_loss: 0.3504 - learning_rate: 0.0012
# Epoch 24/30
# 523/523 ━━━━━━━━━━━━━━━━━━━━ 242s 457ms/step - accuracy: 0.9319 - auc: 0.9928 - loss: 0.2814 - val_accuracy: 0.9104 - val_auc: 0.9862 - val_loss: 0.3584 - learning_rate: 0.0012

# %% [markdown]
# # Model Testing

# %%
from sklearn.metrics import classification_report
# After fixing the test generator to use shuffle=False
# Evaluate the model
test_loss, test_accuracy, test_auc = model1.evaluate(test_generator)
print(f"Test Accuracy: {test_accuracy:.4f}, Test AUC: {test_auc:.4f}")
# Reset generator to ensure proper order
test_generator.reset()
y_pred = model1.predict(test_generator).argmax(axis=1)  # Changed best_model → model
y_true = test_generator.classes

print(classification_report(y_true, y_pred, target_names=test_generator.class_indices.keys()))
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 39s 346ms/step - accuracy: 0.9143 - auc: 0.9898 - loss: 0.3262
# Test Accuracy: 0.9116, Test AUC: 0.9883
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 28s 177ms/step
#               precision    recall  f1-score   support
#
#          CNV       0.90      0.92      0.91       900
#          DME       0.95      0.93      0.94       898
#       DRUSEN       0.91      0.83      0.87       898
#       NORMAL       0.89      0.97      0.93       900
#
#     accuracy                           0.91      3596
#    macro avg       0.91      0.91      0.91      3596
# weighted avg       0.91      0.91      0.91      3596

# %% [markdown]
# # Model Evaluation

# %%
from sklearn.metrics import precision_score, recall_score, f1_score, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# Calculate metrics
precision = precision_score(y_true, y_pred, average='macro')  # 'macro' for class-average
recall = recall_score(y_true, y_pred, average='macro')
f1 = f1_score(y_true, y_pred, average='macro')

print(f"Macro Precision: {precision:.4f}")
print(f"Macro Recall: {recall:.4f}")
print(f"Macro F1-Score: {f1:.4f}\n")

# Confusion matrix
cm = confusion_matrix(y_true, y_pred)
class_names = list(test_generator.class_indices.keys())

# Plot confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', 
            xticklabels=class_names, 
            yticklabels=class_names)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()
# Out:
# Macro Precision: 0.9121
# Macro Recall: 0.9115
# Macro F1-Score: 0.9110

# %%
# Get filenames and class mappings
filenames = test_generator.filenames
class_names = list(test_generator.class_indices.keys())
idx_to_class = {v: k for k, v in test_generator.class_indices.items()}

# Display first 10 samples
print("\nTesting 10 samples:")
for i in range(10):
    actual = idx_to_class[y_true[i]]
    predicted = idx_to_class[y_pred[i]]
    print(f"Sample {i+1}:")
    print(f"  File: {filenames[i]}")
    print(f"  Actual: {actual}")
    print(f"  Predicted: {predicted}")
    print("-" * 50)
# Out:
# Testing 10 samples:
# Sample 1:
#   File: CNV/CNV-1016042-181.jpeg
#   Actual: CNV
#   Predicted: CNV
# --------------------------------------------------
# Sample 2:
#   File: CNV/CNV-1016042-200.jpeg
#   Actual: CNV
#   Predicted: CNV
# --------------------------------------------------
# Sample 3:
#   File: CNV/CNV-1016042-73.jpeg
#   Actual: CNV
#   Predicted: CNV
# --------------------------------------------------
# Sample 4:
#   File: CNV/CNV-103044-11.jpeg
#   Actual: CNV
#   Predicted: CNV
# --------------------------------------------------
# Sample 5:
#   File: CNV/CNV-103044-45.jpeg
#   Actual: CNV
#   Predicted: CNV
# --------------------------------------------------
# Sample 6:
#   File: CNV/CNV-103044-9.jpeg
#   Actual: CNV
#   Predicted: CNV
# --------------------------------------------------
# Sample 7:
#   File: CNV/CNV-1083927-104.jpeg
#   Actual: CNV
#   Predicted: CNV
# --------------------------------------------------
# Sample 8:
#   File: CNV/CNV-1083927-117.jpeg
#   Actual: CNV
#   Predicted: CNV
# --------------------------------------------------
# Sample 9:
#   File: CNV/CNV-1083927-156.jpeg
#   Actual: CNV
#   Predicted: CNV
# --------------------------------------------------
# Sample 10:
#   File: CNV/CNV-1083927-205.jpeg
#   Actual: CNV
#   Predicted: CNV
# --------------------------------------------------

# %% [markdown]
# # Grad-CAM

# %% [markdown]
# # ->CNV

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

def compute_gradcam(model, img_array, target_class_idx, last_conv_layer_name="top_conv"):
    # Create a model that outputs the activations of the last conv layer and the predictions.
    grad_model = tf.keras.models.Model(
        inputs=model.inputs,
        outputs=[model.get_layer(last_conv_layer_name).output, model.output]
    )
    
    with tf.GradientTape() as tape:
        conv_outputs, predictions = grad_model(img_array)
        loss = predictions[:, target_class_idx]
    
    # Compute the gradients of the loss with respect to the conv outputs.
    grads = tape.gradient(loss, conv_outputs)
    
    # Compute the channel-wise mean of the gradients.
    weights = tf.reduce_mean(grads, axis=(0, 1, 2))
    
    # Compute the weighted sum of the feature map channels.
    cam = tf.reduce_sum(tf.multiply(weights, conv_outputs), axis=-1)
    
    # Apply ReLU to the CAM.
    cam = tf.nn.relu(cam)
    
    # Normalize the heatmap.
    cam = cam - tf.reduce_min(cam)
    cam = cam / (tf.reduce_max(cam) + 1e-8)
    cam = cam[0].numpy()  # Remove batch dimension.
    
    # Resize the heatmap to the input image size.
    cam = tf.image.resize(cam[..., tf.newaxis], (img_array.shape[1], img_array.shape[2]))
    cam = tf.squeeze(cam).numpy()
    return cam

# --- Example usage with confidence score ---
img_path = '/kaggle/input/oct-of-retina/RETINA OCT/valid/CNV/CNV-1016042-123.jpeg'
img = tf.keras.preprocessing.image.load_img(img_path, target_size=(224, 224))
img_array = tf.keras.preprocessing.image.img_to_array(img)
img_array = img_array / 255.0  # Rescale as in training
img_array = np.expand_dims(img_array, axis=0)

class_labels = {0: 'CNV', 1: 'DME', 2: 'DRUSEN', 3: 'NORMAL'}

# Make prediction and calculate confidence
preds = model1.predict(img_array)
predicted_class = np.argmax(preds[0])
predicted_label = class_labels[predicted_class]
confidence = np.max(preds[0]) * 100  # Confidence score calculation

# Compute Grad-CAM heatmap
heatmap = compute_gradcam(
    model1, 
    img_array, 
    target_class_idx=predicted_class,
    last_conv_layer_name="top_conv"  # EfficientNetB3 specific layer
)

# Visualization with confidence elements
plt.figure(figsize=(6, 6))
plt.imshow(img)
plt.imshow(heatmap, cmap='jet', alpha=0.4)
plt.title(f"Grad-CAM for EfficientNetB3\nPredicted: {predicted_label} ({confidence:.2f}%)", 
         fontsize=12, fontweight='bold')
plt.axis('off')

# Add confidence text annotation
plt.text(10, 20, f"Confidence: {confidence:.2f}%", 
        fontsize=10, color='white', 
        bbox=dict(facecolor='black', alpha=0.6))

plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 10s 10s/step

# %%
def extract_main_region_from_heatmap(heatmap, threshold=0.5, padding_ratio=0.2):
    
    # Create binary mask
    mask = heatmap >= threshold
    
   
    if not np.any(mask):
        threshold = 0.3 * np.max(heatmap)  
        mask = heatmap >= threshold
    
    if not np.any(mask):
        return None
    
    # Find initial coordinates
    coords = np.argwhere(mask)
    y_min, x_min = coords.min(axis=0)
    y_max, x_max = coords.max(axis=0) + 1
    
    # Calculate proportional padding
    height = y_max - y_min
    width = x_max - x_min
    
    # Add padding (20% of region size by default)
    y_pad = int(height * padding_ratio)
    x_pad = int(width * padding_ratio)
    
    # Apply padding with image boundary checks
    y_min = max(0, y_min - y_pad)
    y_max = min(heatmap.shape[0], y_max + y_pad)
    x_min = max(0, x_min - x_pad)
    x_max = min(heatmap.shape[1], x_max + x_pad)
    
    return (y_min, x_min, y_max, x_max)

# Usage with adjusted parameters
bbox = extract_main_region_from_heatmap(
    heatmap, 
    threshold=0.5,
    padding_ratio=.25  # 20% padding around the region
)

if bbox is None:
    print("No activated region found.")
else:
    print("Adjusted Bounding Box:", bbox)
    
    # Crop with padding
    cropped_img = img.crop((bbox[1], bbox[0], bbox[3], bbox[2]))
    
    # Display
    plt.figure(figsize=(6, 6))
    plt.imshow(cropped_img)
    plt.title("Cropped Main Region of CNV")
    plt.axis("off")
    plt.show()
# Out:
# Adjusted Bounding Box: (36, 8, 139, 178)

# %% [markdown]
# **Patch in the region**

# %%
# Convert original image array back to uint8 for visualization
original_image = (img_array[0] * 255).astype(np.uint8)

# Make a copy of the original image to modify
patched_img = original_image.copy()

# Define patch properties
patch_size = 25  # Adjust as needed
x, y = 70, 75  # Change patch location
patch = np.zeros((patch_size, patch_size, 3), dtype=np.uint8)  # Black patch

# Apply the patch
patched_img[y:y+patch_size, x:x+patch_size] = patch

# Preprocess patched image for model (normalize)
patched_img_array = patched_img / 255.0
patched_img_array = np.expand_dims(patched_img_array, axis=0)

# Display original and patched images side by side
plt.figure(figsize=(10, 5))

# Original Image
plt.subplot(1, 2, 1)
plt.imshow(original_image)
plt.title("Original Image")
plt.axis("off")

# Patched Image
plt.subplot(1, 2, 2)
plt.imshow(patched_img)
plt.title("Patched Image")
plt.axis("off")

plt.show()

# %%
# Predict patched image
patched_preds = model1.predict(patched_img_array)
patched_predicted_class = np.argmax(patched_preds[0])
patched_predicted_label = class_labels[patched_predicted_class]
patched_confidence = np.max(patched_preds[0]) * 100

# Compute Grad-CAM for patched image
patched_heatmap = compute_gradcam(model1, patched_img_array, target_class_idx=patched_predicted_class, last_conv_layer_name="top_conv")

# Display Grad-CAM
plt.figure(figsize=(6, 6))
plt.imshow(patched_img)
plt.imshow(patched_heatmap, cmap='jet', alpha=0.4)
plt.title(f"Grad-CAM for Patched Image\nPredicted: {patched_predicted_label} ({patched_confidence:.2f}%)", fontsize=12, fontweight='bold', color='black')
plt.axis("off")

# Show confidence score inside the image
plt.text(10, 20, f"Confidence: {patched_confidence:.2f}%", fontsize=14, color='white', bbox=dict(facecolor='black', alpha=0.6))

plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step

# %% [markdown]
# **Patch out of the region**

# %%
# Convert original image array back to uint8 for visualization
original_image = (img_array[0] * 255).astype(np.uint8)

# Make a copy of the original image to modify
patched_img = original_image.copy()

# Define patch properties
patch_size = 25  # Adjust as needed
x, y = 185, 45  # Change patch location
patch = np.zeros((patch_size, patch_size, 3), dtype=np.uint8)  # Black patch

# Apply the patch
patched_img[y:y+patch_size, x:x+patch_size] = patch

# Preprocess patched image for model (normalize)
patched_img_array = patched_img / 255.0
patched_img_array = np.expand_dims(patched_img_array, axis=0)

# Display original and patched images side by side
plt.figure(figsize=(10, 5))

# Original Image
plt.subplot(1, 2, 1)
plt.imshow(original_image)
plt.title("Original Image")
plt.axis("off")

# Patched Image
plt.subplot(1, 2, 2)
plt.imshow(patched_img)
plt.title("Patched Image")
plt.axis("off")

plt.show()

# %%
# Predict patched image
patched_preds = model1.predict(patched_img_array)
patched_predicted_class = np.argmax(patched_preds[0])
patched_predicted_label = class_labels[patched_predicted_class]
patched_confidence = np.max(patched_preds[0]) * 100

# Compute Grad-CAM for patched image
patched_heatmap = compute_gradcam(model1, patched_img_array, target_class_idx=patched_predicted_class, last_conv_layer_name="top_conv")

# Display Grad-CAM
plt.figure(figsize=(6, 6))
plt.imshow(patched_img)
plt.imshow(patched_heatmap, cmap='jet', alpha=0.4)
plt.title(f"Grad-CAM for Patched Image\nPredicted: {patched_predicted_label} ({patched_confidence:.2f}%)", fontsize=12, fontweight='bold', color='black')
plt.axis("off")

# Show confidence score inside the image
plt.text(10, 20, f"Confidence: {patched_confidence:.2f}%", fontsize=14, color='white', bbox=dict(facecolor='black', alpha=0.6))

plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step

# %% [markdown]
# # -DME

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

def compute_gradcam(model, img_array, target_class_idx, last_conv_layer_name="top_conv"):
    # Create a model that outputs the activations of the last conv layer and the predictions.
    grad_model = tf.keras.models.Model(
        inputs=model.inputs,
        outputs=[model.get_layer(last_conv_layer_name).output, model.output]
    )
    
    with tf.GradientTape() as tape:
        conv_outputs, predictions = grad_model(img_array)
        loss = predictions[:, target_class_idx]
    
    # Compute the gradients of the loss with respect to the conv outputs.
    grads = tape.gradient(loss, conv_outputs)
    
    # Compute the channel-wise mean of the gradients.
    weights = tf.reduce_mean(grads, axis=(0, 1, 2))
    
    # Compute the weighted sum of the feature map channels.
    cam = tf.reduce_sum(tf.multiply(weights, conv_outputs), axis=-1)
    
    # Apply ReLU to the CAM.
    cam = tf.nn.relu(cam)
    
    # Normalize the heatmap.
    cam = cam - tf.reduce_min(cam)
    cam = cam / (tf.reduce_max(cam) + 1e-8)
    cam = cam[0].numpy()  # Remove batch dimension.
    
    # Resize the heatmap to the input image size.
    cam = tf.image.resize(cam[..., tf.newaxis], (img_array.shape[1], img_array.shape[2]))
    cam = tf.squeeze(cam).numpy()
    return cam

# --- Example usage with confidence score ---
img_path = '/kaggle/input/oct-of-retina/RETINA OCT/valid/DME/DME-1083927-8.jpeg'
img = tf.keras.preprocessing.image.load_img(img_path, target_size=(224, 224))
img_array = tf.keras.preprocessing.image.img_to_array(img)
img_array = img_array / 255.0  # Rescale as in training
img_array = np.expand_dims(img_array, axis=0)

class_labels = {0: 'CNV', 1: 'DME', 2: 'DRUSEN', 3: 'NORMAL'}

# Make prediction and calculate confidence
preds = model1.predict(img_array)
predicted_class = np.argmax(preds[0])
predicted_label = class_labels[predicted_class]
confidence = np.max(preds[0]) * 100  # Confidence score calculation

# Compute Grad-CAM heatmap
heatmap = compute_gradcam(
    model1, 
    img_array, 
    target_class_idx=predicted_class,
    last_conv_layer_name="top_conv"  # EfficientNetB3 specific layer
)

# Visualization with confidence elements
plt.figure(figsize=(6, 6))
plt.imshow(img)
plt.imshow(heatmap, cmap='jet', alpha=0.4)
plt.title(f"Grad-CAM for EfficientNetB3\nPredicted: {predicted_label} ({confidence:.2f}%)", 
         fontsize=12, fontweight='bold')
plt.axis('off')

# Add confidence text annotation
plt.text(10, 20, f"Confidence: {confidence:.2f}%", 
        fontsize=10, color='white', 
        bbox=dict(facecolor='black', alpha=0.6))

plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step

# %%
def extract_main_region_from_heatmap(heatmap, threshold=0.5, padding_ratio=0.2):
    
    # Create binary mask
    mask = heatmap >= threshold
    
   
    if not np.any(mask):
        threshold = 0.3 * np.max(heatmap)  
        mask = heatmap >= threshold
    
    if not np.any(mask):
        return None
    
    # Find initial coordinates
    coords = np.argwhere(mask)
    y_min, x_min = coords.min(axis=0)
    y_max, x_max = coords.max(axis=0) + 1
    
    # Calculate proportional padding
    height = y_max - y_min
    width = x_max - x_min
    
    # Add padding (20% of region size by default)
    y_pad = int(height * padding_ratio)
    x_pad = int(width * padding_ratio)
    
    # Apply padding with image boundary checks
    y_min = max(0, y_min - y_pad)
    y_max = min(heatmap.shape[0], y_max + y_pad)
    x_min = max(0, x_min - x_pad)
    x_max = min(heatmap.shape[1], x_max + x_pad)
    
    return (y_min, x_min, y_max, x_max)

# Usage with adjusted parameters
bbox = extract_main_region_from_heatmap(
    heatmap, 
    threshold=0.5,
    padding_ratio=.20  # 20% padding around the region
)

if bbox is None:
    print("No activated region found.")
else:
    print("Adjusted Bounding Box:", bbox)
    
    # Crop with padding
    cropped_img = img.crop((bbox[1], bbox[0], bbox[3], bbox[2]))
    
    # Display
    plt.figure(figsize=(6, 6))
    plt.imshow(cropped_img)
    plt.title("Cropped Main Region of DME")
    plt.axis("off")
    plt.show()
# Out:
# Adjusted Bounding Box: (16, 0, 74, 224)

# %% [markdown]
# **Patch in the region**

# %%
# Convert original image array back to uint8 for visualization
original_image = (img_array[0] * 255).astype(np.uint8)

# Make a copy of the original image to modify
patched_img = original_image.copy()

# Define patch properties
patch_size = 25  # Adjust as needed
x, y = 130, 40  # Change patch location
patch = np.zeros((patch_size, patch_size, 3), dtype=np.uint8)  # Black patch

# Apply the patch
patched_img[y:y+patch_size, x:x+patch_size] = patch

# Preprocess patched image for model (normalize)
patched_img_array = patched_img / 255.0
patched_img_array = np.expand_dims(patched_img_array, axis=0)

# Display original and patched images side by side
plt.figure(figsize=(10, 5))

# Original Image
plt.subplot(1, 2, 1)
plt.imshow(original_image)
plt.title("Original Image")
plt.axis("off")

# Patched Image
plt.subplot(1, 2, 2)
plt.imshow(patched_img)
plt.title("Patched Image")
plt.axis("off")

plt.show()

# %%
# Predict patched image
patched_preds = model1.predict(patched_img_array)
patched_predicted_class = np.argmax(patched_preds[0])
patched_predicted_label = class_labels[patched_predicted_class]
patched_confidence = np.max(patched_preds[0]) * 100

# Compute Grad-CAM for patched image
patched_heatmap = compute_gradcam(model1, patched_img_array, target_class_idx=patched_predicted_class, last_conv_layer_name="top_conv")

# Display Grad-CAM
plt.figure(figsize=(6, 6))
plt.imshow(patched_img)
plt.imshow(patched_heatmap, cmap='jet', alpha=0.4)
plt.title(f"Grad-CAM for Patched Image\nPredicted: {patched_predicted_label} ({patched_confidence:.2f}%)", fontsize=12, fontweight='bold', color='black')
plt.axis("off")

# Show confidence score inside the image
plt.text(10, 20, f"Confidence: {patched_confidence:.2f}%", fontsize=14, color='white', bbox=dict(facecolor='black', alpha=0.6))

plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step

# %% [markdown]
# **Patch out of the region**

# %%
# Convert original image array back to uint8 for visualization
original_image = (img_array[0] * 255).astype(np.uint8)

# Make a copy of the original image to modify
patched_img = original_image.copy()

# Define patch properties
patch_size = 25  # Adjust as needed
x, y = 55, 90  # Change patch location
patch = np.zeros((patch_size, patch_size, 3), dtype=np.uint8)  # Black patch

# Apply the patch
patched_img[y:y+patch_size, x:x+patch_size] = patch

# Preprocess patched image for model (normalize)
patched_img_array = patched_img / 255.0
patched_img_array = np.expand_dims(patched_img_array, axis=0)

# Display original and patched images side by side
plt.figure(figsize=(10, 5))

# Original Image
plt.subplot(1, 2, 1)
plt.imshow(original_image)
plt.title("Original Image")
plt.axis("off")

# Patched Image
plt.subplot(1, 2, 2)
plt.imshow(patched_img)
plt.title("Patched Image")
plt.axis("off")

plt.show()

# %%
# Predict patched image
patched_preds = model1.predict(patched_img_array)
patched_predicted_class = np.argmax(patched_preds[0])
patched_predicted_label = class_labels[patched_predicted_class]
patched_confidence = np.max(patched_preds[0]) * 100

# Compute Grad-CAM for patched image
patched_heatmap = compute_gradcam(model1, patched_img_array, target_class_idx=patched_predicted_class, last_conv_layer_name="top_conv")

# Display Grad-CAM
plt.figure(figsize=(6, 6))
plt.imshow(patched_img)
plt.imshow(patched_heatmap, cmap='jet', alpha=0.4)
plt.title(f"Grad-CAM for Patched Image\nPredicted: {patched_predicted_label} ({patched_confidence:.2f}%)", fontsize=12, fontweight='bold', color='black')
plt.axis("off")

# Show confidence score inside the image
plt.text(10, 20, f"Confidence: {patched_confidence:.2f}%", fontsize=14, color='white', bbox=dict(facecolor='black', alpha=0.6))

plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step

# %% [markdown]
# # ->DRUSEN

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

def compute_gradcam(model, img_array, target_class_idx, last_conv_layer_name="top_conv"):
    # Create a model that outputs the activations of the last conv layer and the predictions.
    grad_model = tf.keras.models.Model(
        inputs=model.inputs,
        outputs=[model.get_layer(last_conv_layer_name).output, model.output]
    )
    
    with tf.GradientTape() as tape:
        conv_outputs, predictions = grad_model(img_array)
        loss = predictions[:, target_class_idx]
    
    # Compute the gradients of the loss with respect to the conv outputs.
    grads = tape.gradient(loss, conv_outputs)
    
    # Compute the channel-wise mean of the gradients.
    weights = tf.reduce_mean(grads, axis=(0, 1, 2))
    
    # Compute the weighted sum of the feature map channels.
    cam = tf.reduce_sum(tf.multiply(weights, conv_outputs), axis=-1)
    
    # Apply ReLU to the CAM.
    cam = tf.nn.relu(cam)
    
    # Normalize the heatmap.
    cam = cam - tf.reduce_min(cam)
    cam = cam / (tf.reduce_max(cam) + 1e-8)
    cam = cam[0].numpy()  # Remove batch dimension.
    
    # Resize the heatmap to the input image size.
    cam = tf.image.resize(cam[..., tf.newaxis], (img_array.shape[1], img_array.shape[2]))
    cam = tf.squeeze(cam).numpy()
    return cam

# --- Example usage with confidence score ---
img_path = '/kaggle/input/oct-of-retina/RETINA OCT/valid/DRUSEN/DRUSEN-1001666-2.jpeg'
img = tf.keras.preprocessing.image.load_img(img_path, target_size=(224, 224))
img_array = tf.keras.preprocessing.image.img_to_array(img)
img_array = img_array / 255.0  # Rescale as in training
img_array = np.expand_dims(img_array, axis=0)

class_labels = {0: 'CNV', 1: 'DME', 2: 'DRUSEN', 3: 'NORMAL'}

# Make prediction and calculate confidence
preds = model1.predict(img_array)
predicted_class = np.argmax(preds[0])
predicted_label = class_labels[predicted_class]
confidence = np.max(preds[0]) * 100  # Confidence score calculation

# Compute Grad-CAM heatmap
heatmap = compute_gradcam(
    model1, 
    img_array, 
    target_class_idx=predicted_class,
    last_conv_layer_name="top_conv"  # EfficientNetB3 specific layer
)

# Visualization with confidence elements
plt.figure(figsize=(6, 6))
plt.imshow(img)
plt.imshow(heatmap, cmap='jet', alpha=0.4)
plt.title(f"Grad-CAM for EfficientNetB3\nPredicted: {predicted_label} ({confidence:.2f}%)", 
         fontsize=12, fontweight='bold')
plt.axis('off')

# Add confidence text annotation
plt.text(10, 20, f"Confidence: {confidence:.2f}%", 
        fontsize=10, color='white', 
        bbox=dict(facecolor='black', alpha=0.6))

plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step

# %%
def extract_main_region_from_heatmap(heatmap, threshold=0.5, padding_ratio=0.2):
    
    # Create binary mask
    mask = heatmap >= threshold
    
   
    if not np.any(mask):
        threshold = 0.3 * np.max(heatmap)  
        mask = heatmap >= threshold
    
    if not np.any(mask):
        return None
    
    # Find initial coordinates
    coords = np.argwhere(mask)
    y_min, x_min = coords.min(axis=0)
    y_max, x_max = coords.max(axis=0) + 1
    
    # Calculate proportional padding
    height = y_max - y_min
    width = x_max - x_min
    
    # Add padding (20% of region size by default)
    y_pad = int(height * padding_ratio)
    x_pad = int(width * padding_ratio)
    
    # Apply padding with image boundary checks
    y_min = max(0, y_min - y_pad)
    y_max = min(heatmap.shape[0], y_max + y_pad)
    x_min = max(0, x_min - x_pad)
    x_max = min(heatmap.shape[1], x_max + x_pad)
    
    return (y_min, x_min, y_max, x_max)

# Usage with adjusted parameters
bbox = extract_main_region_from_heatmap(
    heatmap, 
    threshold=0.5,
    padding_ratio=.25  # 20% padding around the region
)

if bbox is None:
    print("No activated region found.")
else:
    print("Adjusted Bounding Box:", bbox)
    
    # Crop with padding
    cropped_img = img.crop((bbox[1], bbox[0], bbox[3], bbox[2]))
    
    # Display
    plt.figure(figsize=(6, 6))
    plt.imshow(cropped_img)
    plt.title("Cropped Main Region of DRUSEN")
    plt.axis("off")
    plt.show()
# Out:
# Adjusted Bounding Box: (40, 108, 143, 224)

# %% [markdown]
# **Patch in the region**

# %%
# Convert original image array back to uint8 for visualization
original_image = (img_array[0] * 255).astype(np.uint8)

# Make a copy of the original image to modify
patched_img = original_image.copy()

# Define patch properties
patch_size = 25  # Adjust as needed
x, y = 190, 80  # Change patch location
patch = np.zeros((patch_size, patch_size, 3), dtype=np.uint8)  # Black patch

# Apply the patch
patched_img[y:y+patch_size, x:x+patch_size] = patch

# Preprocess patched image for model (normalize)
patched_img_array = patched_img / 255.0
patched_img_array = np.expand_dims(patched_img_array, axis=0)

# Display original and patched images side by side
plt.figure(figsize=(10, 5))

# Original Image
plt.subplot(1, 2, 1)
plt.imshow(original_image)
plt.title("Original Image")
plt.axis("off")

# Patched Image
plt.subplot(1, 2, 2)
plt.imshow(patched_img)
plt.title("Patched Image")
plt.axis("off")

plt.show()

# %%
# Predict patched image
patched_preds = model1.predict(patched_img_array)
patched_predicted_class = np.argmax(patched_preds[0])
patched_predicted_label = class_labels[patched_predicted_class]
patched_confidence = np.max(patched_preds[0]) * 100

# Compute Grad-CAM for patched image
patched_heatmap = compute_gradcam(model1, patched_img_array, target_class_idx=patched_predicted_class, last_conv_layer_name="top_conv")

# Display Grad-CAM
plt.figure(figsize=(6, 6))
plt.imshow(patched_img)
plt.imshow(patched_heatmap, cmap='jet', alpha=0.4)
plt.title(f"Grad-CAM for Patched Image\nPredicted: {patched_predicted_label} ({patched_confidence:.2f}%)", fontsize=12, fontweight='bold', color='black')
plt.axis("off")

# Show confidence score inside the image
plt.text(10, 20, f"Confidence: {patched_confidence:.2f}%", fontsize=14, color='white', bbox=dict(facecolor='black', alpha=0.6))

plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step

# %% [markdown]
# **Patch out of the region**

# %%
# Convert original image array back to uint8 for visualization
original_image = (img_array[0] * 255).astype(np.uint8)

# Make a copy of the original image to modify
patched_img = original_image.copy()

# Define patch properties
patch_size = 25  # Adjust as needed
x, y = 50, 70  # Change patch location
patch = np.zeros((patch_size, patch_size, 3), dtype=np.uint8)  # Black patch

# Apply the patch
patched_img[y:y+patch_size, x:x+patch_size] = patch

# Preprocess patched image for model (normalize)
patched_img_array = patched_img / 255.0
patched_img_array = np.expand_dims(patched_img_array, axis=0)

# Display original and patched images side by side
plt.figure(figsize=(10, 5))

# Original Image
plt.subplot(1, 2, 1)
plt.imshow(original_image)
plt.title("Original Image")
plt.axis("off")

# Patched Image
plt.subplot(1, 2, 2)
plt.imshow(patched_img)
plt.title("Patched Image")
plt.axis("off")

plt.show()

# %%
# Predict patched image
patched_preds = model1.predict(patched_img_array)
patched_predicted_class = np.argmax(patched_preds[0])
patched_predicted_label = class_labels[patched_predicted_class]
patched_confidence = np.max(patched_preds[0]) * 100

# Compute Grad-CAM for patched image
patched_heatmap = compute_gradcam(model1, patched_img_array, target_class_idx=patched_predicted_class, last_conv_layer_name="top_conv")

# Display Grad-CAM
plt.figure(figsize=(6, 6))
plt.imshow(patched_img)
plt.imshow(patched_heatmap, cmap='jet', alpha=0.4)
plt.title(f"Grad-CAM for Patched Image\nPredicted: {patched_predicted_label} ({patched_confidence:.2f}%)", fontsize=12, fontweight='bold', color='black')
plt.axis("off")

# Show confidence score inside the image
plt.text(10, 20, f"Confidence: {patched_confidence:.2f}%", fontsize=14, color='white', bbox=dict(facecolor='black', alpha=0.6))

plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step

# %% [markdown]
# # ->NORMAL

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

def compute_gradcam(model, img_array, target_class_idx, last_conv_layer_name="top_conv"):
    # Create a model that outputs the activations of the last conv layer and the predictions.
    grad_model = tf.keras.models.Model(
        inputs=model.inputs,
        outputs=[model.get_layer(last_conv_layer_name).output, model.output]
    )
    
    with tf.GradientTape() as tape:
        conv_outputs, predictions = grad_model(img_array)
        loss = predictions[:, target_class_idx]
    
    # Compute the gradients of the loss with respect to the conv outputs.
    grads = tape.gradient(loss, conv_outputs)
    
    # Compute the channel-wise mean of the gradients.
    weights = tf.reduce_mean(grads, axis=(0, 1, 2))
    
    # Compute the weighted sum of the feature map channels.
    cam = tf.reduce_sum(tf.multiply(weights, conv_outputs), axis=-1)
    
    # Apply ReLU to the CAM.
    cam = tf.nn.relu(cam)
    
    # Normalize the heatmap.
    cam = cam - tf.reduce_min(cam)
    cam = cam / (tf.reduce_max(cam) + 1e-8)
    cam = cam[0].numpy()  # Remove batch dimension.
    
    # Resize the heatmap to the input image size.
    cam = tf.image.resize(cam[..., tf.newaxis], (img_array.shape[1], img_array.shape[2]))
    cam = tf.squeeze(cam).numpy()
    return cam

# --- Example usage with confidence score ---
img_path = '/kaggle/input/oct-of-retina/RETINA OCT/valid/NORMAL/NORMAL-1014715-10.jpeg'
img = tf.keras.preprocessing.image.load_img(img_path, target_size=(224, 224))
img_array = tf.keras.preprocessing.image.img_to_array(img)
img_array = img_array / 255.0  # Rescale as in training
img_array = np.expand_dims(img_array, axis=0)

class_labels = {0: 'CNV', 1: 'DME', 2: 'DRUSEN', 3: 'NORMAL'}

# Make prediction and calculate confidence
preds = model1.predict(img_array)
predicted_class = np.argmax(preds[0])
predicted_label = class_labels[predicted_class]
confidence = np.max(preds[0]) * 100  # Confidence score calculation

# Compute Grad-CAM heatmap
heatmap = compute_gradcam(
    model1, 
    img_array, 
    target_class_idx=predicted_class,
    last_conv_layer_name="top_conv"  # EfficientNetB3 specific layer
)

# Visualization with confidence elements
plt.figure(figsize=(6, 6))
plt.imshow(img)
plt.imshow(heatmap, cmap='jet', alpha=0.4)
plt.title(f"Grad-CAM for EfficientNetB3\nPredicted: {predicted_label} ({confidence:.2f}%)", 
         fontsize=12, fontweight='bold')
plt.axis('off')

# Add confidence text annotation
plt.text(10, 20, f"Confidence: {confidence:.2f}%", 
        fontsize=10, color='white', 
        bbox=dict(facecolor='black', alpha=0.6))

plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step

# %%
def extract_main_region_from_heatmap(heatmap, threshold=0.5, padding_ratio=0.2):
    
    # Create binary mask
    mask = heatmap >= threshold
    
   
    if not np.any(mask):
        threshold = 0.3 * np.max(heatmap)  
        mask = heatmap >= threshold
    
    if not np.any(mask):
        return None
    
    # Find initial coordinates
    coords = np.argwhere(mask)
    y_min, x_min = coords.min(axis=0)
    y_max, x_max = coords.max(axis=0) + 1
    
    # Calculate proportional padding
    height = y_max - y_min
    width = x_max - x_min
    
    # Add padding (20% of region size by default)
    y_pad = int(height * padding_ratio)
    x_pad = int(width * padding_ratio)
    
    # Apply padding with image boundary checks
    y_min = max(0, y_min - y_pad)
    y_max = min(heatmap.shape[0], y_max + y_pad)
    x_min = max(0, x_min - x_pad)
    x_max = min(heatmap.shape[1], x_max + x_pad)
    
    return (y_min, x_min, y_max, x_max)

# Usage with adjusted parameters
bbox = extract_main_region_from_heatmap(
    heatmap, 
    threshold=0.5,
    padding_ratio=.20  # 20% padding around the region
)

if bbox is None:
    print("No activated region found.")
else:
    print("Adjusted Bounding Box:", bbox)
    
    # Crop with padding
    cropped_img = img.crop((bbox[1], bbox[0], bbox[3], bbox[2]))
    
    # Display
    plt.figure(figsize=(6, 6))
    plt.imshow(cropped_img)
    plt.title("Cropped Main Region of NORMAL")
    plt.axis("off")
    plt.show()
# Out:
# Adjusted Bounding Box: (0, 4, 118, 209)

# %% [markdown]
# **Patch in the region**

# %%
# Convert original image array back to uint8 for visualization
original_image = (img_array[0] * 255).astype(np.uint8)

# Make a copy of the original image to modify
patched_img = original_image.copy()

# Define patch properties
patch_size = 25  # Adjust as needed
x, y = 120, 40  # Change patch location
patch = np.zeros((patch_size, patch_size, 3), dtype=np.uint8)  # Black patch

# Apply the patch
patched_img[y:y+patch_size, x:x+patch_size] = patch

# Preprocess patched image for model (normalize)
patched_img_array = patched_img / 255.0
patched_img_array = np.expand_dims(patched_img_array, axis=0)

# Display original and patched images side by side
plt.figure(figsize=(10, 5))

# Original Image
plt.subplot(1, 2, 1)
plt.imshow(original_image)
plt.title("Original Image")
plt.axis("off")

# Patched Image
plt.subplot(1, 2, 2)
plt.imshow(patched_img)
plt.title("Patched Image")
plt.axis("off")

plt.show()

# %%
# Predict patched image
patched_preds = model1.predict(patched_img_array)
patched_predicted_class = np.argmax(patched_preds[0])
patched_predicted_label = class_labels[patched_predicted_class]
patched_confidence = np.max(patched_preds[0]) * 100

# Compute Grad-CAM for patched image
patched_heatmap = compute_gradcam(model1, patched_img_array, target_class_idx=patched_predicted_class, last_conv_layer_name="top_conv")

# Display Grad-CAM
plt.figure(figsize=(6, 6))
plt.imshow(patched_img)
plt.imshow(patched_heatmap, cmap='jet', alpha=0.4)
plt.title(f"Grad-CAM for Patched Image\nPredicted: {patched_predicted_label} ({patched_confidence:.2f}%)", fontsize=12, fontweight='bold', color='black')
plt.axis("off")

# Show confidence score inside the image
plt.text(10, 20, f"Confidence: {patched_confidence:.2f}%", fontsize=14, color='white', bbox=dict(facecolor='black', alpha=0.6))

plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step

# %% [markdown]
# **Patch out of the region**

# %%
# Convert original image array back to uint8 for visualization
original_image = (img_array[0] * 255).astype(np.uint8)

# Make a copy of the original image to modify
patched_img = original_image.copy()

# Define patch properties
patch_size = 25  # Adjust as needed
x, y = 195, 60  # Change patch location
patch = np.zeros((patch_size, patch_size, 3), dtype=np.uint8)  # Black patch

# Apply the patch
patched_img[y:y+patch_size, x:x+patch_size] = patch

# Preprocess patched image for model (normalize)
patched_img_array = patched_img / 255.0
patched_img_array = np.expand_dims(patched_img_array, axis=0)

# Display original and patched images side by side
plt.figure(figsize=(10, 5))

# Original Image
plt.subplot(1, 2, 1)
plt.imshow(original_image)
plt.title("Original Image")
plt.axis("off")

# Patched Image
plt.subplot(1, 2, 2)
plt.imshow(patched_img)
plt.title("Patched Image")
plt.axis("off")

plt.show()

# %%
# Predict patched image
patched_preds = model1.predict(patched_img_array)
patched_predicted_class = np.argmax(patched_preds[0])
patched_predicted_label = class_labels[patched_predicted_class]
patched_confidence = np.max(patched_preds[0]) * 100

# Compute Grad-CAM for patched image
patched_heatmap = compute_gradcam(model1, patched_img_array, target_class_idx=patched_predicted_class, last_conv_layer_name="top_conv")

# Display Grad-CAM
plt.figure(figsize=(6, 6))
plt.imshow(patched_img)
plt.imshow(patched_heatmap, cmap='jet', alpha=0.4)
plt.title(f"Grad-CAM for Patched Image\nPredicted: {patched_predicted_label} ({patched_confidence:.2f}%)", fontsize=12, fontweight='bold', color='black')
plt.axis("off")

# Show confidence score inside the image
plt.text(10, 20, f"Confidence: {patched_confidence:.2f}%", fontsize=14, color='white', bbox=dict(facecolor='black', alpha=0.6))

plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
