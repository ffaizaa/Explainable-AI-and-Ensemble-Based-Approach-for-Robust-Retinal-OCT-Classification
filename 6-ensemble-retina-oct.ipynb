# %%
import os

# Check the contents of the input directory
print("Contents of /kaggle/input:")
print(os.listdir('/kaggle/input'))

# Use the correct path including the dataset name folder
dataset_folder = '/kaggle/input/oct-of-retina/RETINA OCT'
print(f"Contents of {dataset_folder}:")
print(os.listdir(dataset_folder))
# Out:
# Contents of /kaggle/input:
# ['custom_cnn', 'oct-of-retina']
# Contents of /kaggle/input/oct-of-retina/RETINA OCT:
# ['valid', 'test', 'train']

# %% [markdown]
# # **DATASET ANALYSIS**

# %%
import os

def analyze_dataset(base_path):
    # Lists to store the splits we want to analyze
    splits = ['train', 'test', 'valid']
    
    for split in splits:
        split_path = os.path.join(base_path, split)
        
        # Check if the split directory exists
        if not os.path.exists(split_path):
            print(f"\nWarning: {split} directory not found!")
            continue
            
        # Get all classes (subdirectories) in this split
        classes = os.listdir(split_path)
        
        print(f"\n{split.upper()} SET:")
        print(f"Number of classes: {len(classes)}")
        print("Files per class:")
        
        # Count files in each class
        for class_name in classes:
            class_path = os.path.join(split_path, class_name)
            if os.path.isdir(class_path):  # Make sure it's a directory
                num_files = len(os.listdir(class_path))
                print(f"- {class_name}: {num_files} files")

# Path to the dataset
dataset_path = '/kaggle/input/oct-of-retina/RETINA OCT'

print("Dataset Analysis:")
print("=" * 50)
analyze_dataset(dataset_path)
# Out:
# Dataset Analysis:
# ==================================================
#
# TRAIN SET:
# Number of classes: 4
# Files per class:
# - DRUSEN: 4147 files
# - CNV: 4195 files
# - NORMAL: 4194 files
# - DME: 4179 files
#
# TEST SET:
# Number of classes: 4
# Files per class:
# - DRUSEN: 898 files
# - CNV: 900 files
# - NORMAL: 900 files
# - DME: 898 files
#
# VALID SET:
# Number of classes: 4
# Files per class:
# - DRUSEN: 895 files
# - CNV: 900 files
# - NORMAL: 900 files
# - DME: 899 files

# %%
# Define base path and subdirectories
dataset_path = "/kaggle/input/oct-of-retina/RETINA OCT"
train_dir = os.path.join(dataset_path, "train")
val_dir = os.path.join(dataset_path, "valid")
test_dir = os.path.join(dataset_path, "test")

print("Checking if directories exist:")
print(f"Train directory exists: {os.path.exists(train_dir)}")
print(f"Validation directory exists: {os.path.exists(val_dir)}")
print(f"Test directory exists: {os.path.exists(test_dir)}")

# Print example paths to verify structure
print("\nDirectory paths:")
print(f"Training: {train_dir}")
print(f"Validation: {val_dir}")
print(f"Testing: {test_dir}")
# Out:
# Checking if directories exist:
# Train directory exists: True
# Validation directory exists: True
# Test directory exists: True
#
# Directory paths:
# Training: /kaggle/input/oct-of-retina/RETINA OCT/train
# Validation: /kaggle/input/oct-of-retina/RETINA OCT/valid
# Testing: /kaggle/input/oct-of-retina/RETINA OCT/test

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Flatten, Dropout, GlobalAveragePooling2D
from tensorflow.keras.optimizers import Adam,SGD
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping, ModelCheckpoint
import os
import numpy as np

# %% [markdown]
# # Visualizing Raw images

# %%
import matplotlib.pyplot as plt
import cv2
import random

# Function to visualize sample images from each class
def visualize_samples(data_dir, num_samples=5):
    
    classes = os.listdir(data_dir)
    classes = [cls for cls in classes if os.path.isdir(os.path.join(data_dir, cls))]  # Filter valid directories

    print(f"\nVisualizing samples from: {data_dir}")
    print(f"Classes: {classes}")
    
    plt.figure(figsize=(15, len(classes) * 3))
    
    for idx, class_name in enumerate(classes):
        class_dir = os.path.join(data_dir, class_name)
        image_files = os.listdir(class_dir)
        image_files = [f for f in image_files if f.lower().endswith(('png', 'jpg', 'jpeg'))]
        
        # Randomly select images
        selected_images = random.sample(image_files, min(len(image_files), num_samples))
        
        for j, img_file in enumerate(selected_images):
            img_path = os.path.join(class_dir, img_file)
            img = cv2.imread(img_path)  # Read as RGB
            img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)  # Convert BGR to RGB
            
            # Plot image
            plt.subplot(len(classes), num_samples, idx * num_samples + j + 1)
            plt.imshow(img)
            plt.title(f"{class_name}")
            plt.axis('off')
    
    plt.tight_layout()
    plt.show()

# Example usage:
train_dir = "/kaggle/input/oct-of-retina/RETINA OCT/train"  # Change this to the actual path
visualize_samples(train_dir)
# Out:
# Visualizing samples from: /kaggle/input/oct-of-retina/RETINA OCT/train
# Classes: ['DRUSEN', 'CNV', 'NORMAL', 'DME']

# %% [markdown]
# # Preprocessing and Augmentation

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=5,
    width_shift_range=0.1,
    height_shift_range=0.1,
    shear_range=0.1,
    zoom_range=0.1,
    horizontal_flip=True,
    brightness_range=[0.8, 1.2],
    fill_mode='nearest'
)
val_test_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
    '/kaggle/input/oct-of-retina/RETINA OCT/train',
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical',
    shuffle=True,
    color_mode='rgb'
)

val_generator = val_test_datagen.flow_from_directory(
    '/kaggle/input/oct-of-retina/RETINA OCT/valid',
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical',
    shuffle=False,
    color_mode='rgb'
)

test_generator = val_test_datagen.flow_from_directory(
    '/kaggle/input/oct-of-retina/RETINA OCT/test',
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical',
    shuffle=False,
    color_mode='rgb'
)
# Out:
# Found 16715 images belonging to 4 classes.
# Found 3594 images belonging to 4 classes.
# Found 3596 images belonging to 4 classes.

# %% [markdown]
# # Visualize the preprocessed image

# %%
def visualize_augmented_samples(generator, num_samples=5):
    # Get class names and indices from the generator
    class_indices = generator.class_indices
    class_names = sorted(class_indices.keys(), key=lambda x: class_indices[x])
    num_classes = len(class_names)
    
    # Initialize storage for samples
    samples = {i: [] for i in range(num_classes)}
    max_batches = 10  # Safety limit to prevent infinite loops
    
    # Collect samples from generator batches
    for _ in range(max_batches):
        images, labels = next(generator)
        for img, label in zip(images, labels):
            class_idx = label.argmax()
            if len(samples[class_idx]) < num_samples:
                samples[class_idx].append(img)
        
        # Check if we've collected enough samples for all classes
        if all(len(v) >= num_samples for v in samples.values()):
            break
    
    # Create plot
    plt.figure(figsize=(15, num_classes * 3))
    
    for idx, class_name in enumerate(class_names):
        class_imgs = samples[idx][:num_samples]  # Get up to num_samples
        
        for j, img in enumerate(class_imgs):
            # Calculate position in grid
            position = idx * num_samples + j + 1
            plt.subplot(num_classes, num_samples, position)
            
            # Display image (assuming generator outputs [0,1] float values)
            plt.imshow(img)
            plt.title(f"{class_name}")
            plt.axis('off')

    plt.tight_layout()
    plt.show()

# Example usage
visualize_augmented_samples(train_generator)

# %% [markdown]
# # Densenet121 model

# %%
from tensorflow.keras.layers import Input, Lambda, GlobalAveragePooling2D, Dense, Dropout, BatchNormalization, ReLU
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.applications import DenseNet121
from tensorflow.keras.applications.densenet import preprocess_input as densenet_preprocess
from tensorflow.keras.models import Model
from tensorflow.keras.regularizers import l2


def create_model_DenseNet121(input_shape, num_classes, fine_tune_at=-20, dropout_rate=0.5, l2_lambda=1e-4, learning_rate=0.01):
    inputs = Input(shape=input_shape)
    # Since the generator already outputs [0,1], multiply by 255 before applying DenseNet preprocessing
    x = Lambda(lambda x: densenet_preprocess(x * 255.0))(inputs)
    base_model = DenseNet121(weights='imagenet', include_top=False, input_tensor=x, input_shape=input_shape)
    if fine_tune_at is not None:
        if fine_tune_at < 0:
            fine_tune_at = len(base_model.layers) + fine_tune_at
        base_model.trainable = True
        for layer in base_model.layers[:fine_tune_at]:
            layer.trainable = False
    else:
        base_model.trainable = False
    x = GlobalAveragePooling2D()(base_model.output)
    x = Dense(512, kernel_regularizer=l2(l2_lambda))(x)
    x = BatchNormalization()(x)
    x = ReLU()(x)
    x = Dropout(dropout_rate)(x)
    x = Dense(256, kernel_regularizer=l2(l2_lambda))(x)
    x = BatchNormalization()(x)
    x = ReLU()(x)
    x = Dropout(dropout_rate * 0.7)(x)
    predictions = Dense(num_classes, activation='softmax')(x)
    model = Model(inputs=inputs, outputs=predictions)
    model.compile(optimizer=SGD(learning_rate=learning_rate, momentum=0.9, nesterov=True),
                  loss='categorical_crossentropy',
                  metrics=['accuracy', tf.keras.metrics.AUC()])
    return model

# %%
# Instantiate the model
model2 = create_model_DenseNet121(input_shape=(224, 224, 3), num_classes=4)


from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.models import Model

# Define callbacks
callbacks = [
    EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True),
    ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3),
]
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet121_weights_tf_dim_ordering_tf_kernels_notop.h5
# 29084464/29084464 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %% [markdown]
# # Model Training

# %%
 history = model2.fit(
    train_generator,  
    validation_data=val_generator,
    epochs=30,
    callbacks=callbacks,
    verbose=1
)

model2.save('RETINAxDenseNet121.keras')
# Out:
# Epoch 1/30
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 523/523 ━━━━━━━━━━━━━━━━━━━━ 423s 742ms/step - accuracy: 0.6931 - auc: 0.8912 - loss: 0.8848 - val_accuracy: 0.8197 - val_auc: 0.9627 - val_loss: 0.5899 - learning_rate: 0.0100
# Epoch 2/30
# 523/523 ━━━━━━━━━━━━━━━━━━━━ 258s 487ms/step - accuracy: 0.8420 - auc: 0.9662 - loss: 0.5382 - val_accuracy: 0.8734 - val_auc: 0.9777 - val_loss: 0.4543 - learning_rate: 0.0100
# Epoch 3/30
# 523/523 ━━━━━━━━━━━━━━━━━━━━ 256s 483ms/step - accuracy: 0.8692 - auc: 0.9734 - loss: 0.4841 - val_accuracy: 0.7846 - val_auc: 0.9384 - val_loss: 0.8052 - learning_rate: 0.0100
# Epoch 4/30
# 523/523 ━━━━━━━━━━━━━━━━━━━━ 258s 487ms/step - accuracy: 0.8801 - auc: 0.9784 - loss: 0.4397 - val_accuracy: 0.8400 - val_auc: 0.9637 - val_loss: 0.5813 - learning_rate: 0.0100
# Epoch 5/30
# 523/523 ━━━━━━━━━━━━━━━━━━━━ 253s 477ms/step - accuracy: 0.8828 - auc: 0.9800 - loss: 0.4268 - val_accuracy: 0.8804 - val_auc: 0.9816 - val_loss: 0.4143 - learning_rate: 0.0100
# Epoch 6/30
# 523/523 ━━━━━━━━━━━━━━━━━━━━ 250s 473ms/step - accuracy: 0.8826 - auc: 0.9795 - loss: 0.4285 - val_accuracy: 0.8809 - val_auc: 0.9804 - val_loss: 0.4256 - learning_rate: 0.0100
# Epoch 7/30
# 523/523 ━━━━━━━━━━━━━━━━━━━━ 250s 473ms/step - accuracy: 0.8937 - auc: 0.9829 - loss: 0.3951 - val_accuracy: 0.8843 - val_auc: 0.9808 - val_loss: 0.4230 - learning_rate: 0.0100
# Epoch 8/30
# 523/523 ━━━━━━━━━━━━━━━━━━━━ 249s 470ms/step - accuracy: 0.8994 - auc: 0.9845 - loss: 0.3784 - val_accuracy: 0.8625 - val_auc: 0.9746 - val_loss: 0.4874 - learning_rate: 0.0100
# Epoch 9/30
# 523/523 ━━━━━━━━━━━━━━━━━━━━ 248s 468ms/step - accuracy: 0.9042 - auc: 0.9858 - loss: 0.3619 - val_accuracy: 0.8804 - val_auc: 0.9831 - val_loss: 0.4003 - learning_rate: 0.0050
# Epoch 10/30
# 523/523 ━━━━━━━━━━━━━━━━━━━━ 249s 470ms/step - accuracy: 0.9091 - auc: 0.9877 - loss: 0.3449 - val_accuracy: 0.9079 - val_auc: 0.9875 - val_loss: 0.3474 - learning_rate: 0.0050
# Epoch 11/30
# 523/523 ━━━━━━━━━━━━━━━━━━━━ 249s 469ms/step - accuracy: 0.9161 - auc: 0.9881 - loss: 0.3366 - val_accuracy: 0.8954 - val_auc: 0.9857 - val_loss: 0.3734 - learning_rate: 0.0050
# Epoch 12/30
# 523/523 ━━━━━━━━━━━━━━━━━━━━ 249s 471ms/step - accuracy: 0.9153 - auc: 0.9890 - loss: 0.3294 - val_accuracy: 0.9004 - val_auc: 0.9860 - val_loss: 0.3634 - learning_rate: 0.0050
# Epoch 13/30
# 523/523 ━━━━━━━━━━━━━━━━━━━━ 250s 472ms/step - accuracy: 0.9141 - auc: 0.9886 - loss: 0.3303 - val_accuracy: 0.9062 - val_auc: 0.9874 - val_loss: 0.3485 - learning_rate: 0.0050
# Epoch 14/30
# 523/523 ━━━━━━━━━━━━━━━━━━━━ 254s 480ms/step - accuracy: 0.9233 - auc: 0.9904 - loss: 0.3048 - val_accuracy: 0.8926 - val_auc: 0.9844 - val_loss: 0.3808 - learning_rate: 0.0025
# Epoch 15/30
# 523/523 ━━━━━━━━━━━━━━━━━━━━ 248s 468ms/step - accuracy: 0.9241 - auc: 0.9913 - loss: 0.2992 - val_accuracy: 0.9007 - val_auc: 0.9853 - val_loss: 0.3724 - learning_rate: 0.0025

# %% [markdown]
# # Model Testing

# %%
from sklearn.metrics import classification_report
# After fixing the test generator to use shuffle=False
# Evaluate the model
test_loss, test_accuracy, test_auc = model2.evaluate(test_generator)
print(f"Test Accuracy: {test_accuracy:.4f}, Test AUC: {test_auc:.4f}")
# Reset generator to ensure proper order
test_generator.reset()
y_pred = model2.predict(test_generator).argmax(axis=1)  # Changed best_model → model
y_true = test_generator.classes

print(classification_report(y_true, y_pred, target_names=test_generator.class_indices.keys()))
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 43s 379ms/step - accuracy: 0.8939 - auc: 0.9839 - loss: 0.3850
# Test Accuracy: 0.8991, Test AUC: 0.9844
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 26s 169ms/step
#               precision    recall  f1-score   support
#
#          CNV       0.92      0.89      0.91       900
#          DME       0.94      0.95      0.94       898
#       DRUSEN       0.91      0.78      0.84       898
#       NORMAL       0.84      0.98      0.91       900
#
#     accuracy                           0.90      3596
#    macro avg       0.90      0.90      0.90      3596
# weighted avg       0.90      0.90      0.90      3596

# %% [markdown]
# # Ensemble Custom CNN +densenet121

# %%
from tensorflow.keras import layers, models

# Load Custom CNN
custom_cnn = keras.models.load_model('/kaggle/input/custom_cnn/keras/default/1/RETINAxCustom.keras', safe_mode=False)

# Load DenseNet (already trained as model2)
densenet_model = model2

# Freeze models
custom_cnn.trainable = False
densenet_model.trainable = False

# Create a fresh Input
input_layer = layers.Input(shape=(224, 224, 3))

# **Wrap them into new layers with unique names!**
custom_out = models.Model(custom_cnn.input, custom_cnn.output, name="custom_cnn_wrapper")(input_layer)
densenet_out = models.Model(densenet_model.input, densenet_model.output, name="densenet_wrapper")(input_layer)

# Weighted outputs
weighted_custom = layers.Lambda(lambda x: x * 0.60, name="weighted_custom")(custom_out)
weighted_densenet = layers.Lambda(lambda x: x * 0.40, name="weighted_densenet")(densenet_out)

# Add outputs
ensemble_output = layers.Add(name='ensemble_output')([weighted_custom, weighted_densenet])

# Final model
ensemble_model = models.Model(inputs=input_layer, outputs=ensemble_output)

# Compile
ensemble_model.compile(optimizer='adam',
                       loss='categorical_crossentropy',
                       metrics=['accuracy', keras.metrics.AUC(name='auc')])

# %% [markdown]
# # Ensemble model test

# %%
test_loss, test_accuracy, test_auc = ensemble_model.evaluate(test_generator)
print(f"Test Accuracy: {test_accuracy:.4f}, Test AUC: {test_auc:.4f}")

test_generator.reset()
y_pred = ensemble_model.predict(test_generator).argmax(axis=1)  # Changed best_model → model
y_true = test_generator.classes

print(classification_report(y_true, y_pred, target_names=test_generator.class_indices.keys()))
# Out:
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 29s 166ms/step - accuracy: 0.9266 - auc: 0.9899 - loss: 0.2198
# Test Accuracy: 0.9360, Test AUC: 0.9921
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 28s 191ms/step
#               precision    recall  f1-score   support
#
#          CNV       0.95      0.91      0.93       900
#          DME       0.94      0.97      0.95       898
#       DRUSEN       0.94      0.89      0.91       898
#       NORMAL       0.92      0.97      0.95       900
#
#     accuracy                           0.94      3596
#    macro avg       0.94      0.94      0.94      3596
# weighted avg       0.94      0.94      0.94      3596

# %% [markdown]
# # Ensemble Model Evaluation

# %%
from sklearn.metrics import precision_score, recall_score, f1_score, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# Calculate metrics
precision = precision_score(y_true, y_pred, average='macro')  # 'macro' for class-average
recall = recall_score(y_true, y_pred, average='macro')
f1 = f1_score(y_true, y_pred, average='macro')

print(f"Macro Precision: {precision:.4f}")
print(f"Macro Recall: {recall:.4f}")
print(f"Macro F1-Score: {f1:.4f}\n")

# Confusion matrix
cm = confusion_matrix(y_true, y_pred)
class_names = list(test_generator.class_indices.keys())

# Plot confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', 
            xticklabels=class_names, 
            yticklabels=class_names)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()
# Out:
# Macro Precision: 0.9363
# Macro Recall: 0.9360
# Macro F1-Score: 0.9358

# %%
# Get filenames and class mappings
filenames = test_generator.filenames
class_names = list(test_generator.class_indices.keys())
idx_to_class = {v: k for k, v in test_generator.class_indices.items()}

# Display first 10 samples
print("\nTesting 10 samples:")
for i in range(10):
    actual = idx_to_class[y_true[i]]
    predicted = idx_to_class[y_pred[i]]
    print(f"Sample {i+1}:")
    print(f"  File: {filenames[i]}")
    print(f"  Actual: {actual}")
    print(f"  Predicted: {predicted}")
    print("-" * 50)
# Out:
# Testing 10 samples:
# Sample 1:
#   File: CNV/CNV-1016042-181.jpeg
#   Actual: CNV
#   Predicted: CNV
# --------------------------------------------------
# Sample 2:
#   File: CNV/CNV-1016042-200.jpeg
#   Actual: CNV
#   Predicted: CNV
# --------------------------------------------------
# Sample 3:
#   File: CNV/CNV-1016042-73.jpeg
#   Actual: CNV
#   Predicted: CNV
# --------------------------------------------------
# Sample 4:
#   File: CNV/CNV-103044-11.jpeg
#   Actual: CNV
#   Predicted: CNV
# --------------------------------------------------
# Sample 5:
#   File: CNV/CNV-103044-45.jpeg
#   Actual: CNV
#   Predicted: CNV
# --------------------------------------------------
# Sample 6:
#   File: CNV/CNV-103044-9.jpeg
#   Actual: CNV
#   Predicted: CNV
# --------------------------------------------------
# Sample 7:
#   File: CNV/CNV-1083927-104.jpeg
#   Actual: CNV
#   Predicted: CNV
# --------------------------------------------------
# Sample 8:
#   File: CNV/CNV-1083927-117.jpeg
#   Actual: CNV
#   Predicted: DME
# --------------------------------------------------
# Sample 9:
#   File: CNV/CNV-1083927-156.jpeg
#   Actual: CNV
#   Predicted: DME
# --------------------------------------------------
# Sample 10:
#   File: CNV/CNV-1083927-205.jpeg
#   Actual: CNV
#   Predicted: CNV
# --------------------------------------------------

# %% [markdown]
# # Grad-CAM

# %% [markdown]
# # ->CNV

# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

def compute_gradcam(model, img_array, target_class_idx, 
                    backbone_model_name="densenet_wrapper", 
                    last_conv_layer_name="conv5_block16_concat"):

    # Access the backbone model (DenseNet) inside the ensemble
    backbone_model = model.get_layer(backbone_model_name)

    # Create a sub-model for Grad-CAM
    grad_model = tf.keras.models.Model(
        inputs=backbone_model.input,
        outputs=[backbone_model.get_layer(last_conv_layer_name).output, backbone_model.output]
    )
    
    # Forward pass + record gradients
    with tf.GradientTape() as tape:
        conv_outputs, predictions = grad_model(img_array)
        loss = predictions[:, target_class_idx]
    
    # Compute gradients of the output w.r.t. last conv layer
    grads = tape.gradient(loss, conv_outputs)
    weights = tf.reduce_mean(grads, axis=(0, 1, 2))
    
    # Weighted sum of feature maps
    cam = tf.reduce_sum(tf.multiply(weights, conv_outputs), axis=-1)
    cam = tf.nn.relu(cam)  # ReLU activation
    
    # Normalize CAM
    cam = cam - tf.reduce_min(cam)
    cam = cam / (tf.reduce_max(cam) + 1e-8)
    cam = cam[0].numpy()  # Remove batch dimension
    
    # Resize CAM to input image size
    cam = tf.image.resize(cam[..., tf.newaxis], (img_array.shape[1], img_array.shape[2]))
    cam = tf.squeeze(cam).numpy()
    
    return cam

# --- Load and preprocess your test image ---
img_path = '/kaggle/input/oct-of-retina/RETINA OCT/valid/CNV/CNV-1112835-288.jpeg'

# Load and preprocess
img = tf.keras.preprocessing.image.load_img(img_path, target_size=(224, 224))
img_array = tf.keras.preprocessing.image.img_to_array(img)
img_array = img_array / 255.0  # Normalize as in training
img_array = np.expand_dims(img_array, axis=0)  # Make batch dimension

# --- Class labels ---
class_labels = {0: 'CNV', 1: 'DME', 2: 'DRUSEN', 3: 'NORMAL'}

# --- Predict using your ENSEMBLE model ---
preds = ensemble_model.predict(img_array)
predicted_class = np.argmax(preds[0])
predicted_label = class_labels[predicted_class]
confidence = np.max(preds[0]) * 100

# --- Compute Grad-CAM from DenseNet part inside the ensemble ---
heatmap = compute_gradcam(ensemble_model, img_array, target_class_idx=predicted_class)

# --- Visualization ---
plt.figure(figsize=(6, 6))
plt.imshow(img)
plt.imshow(heatmap, cmap='jet', alpha=0.4)  # Overlay heatmap
plt.title(f"Grad-CAM\nPredicted: {predicted_label} ({confidence:.2f}%)", 
         fontsize=12, fontweight='bold')
plt.axis('off')
plt.text(10, 20, f"Confidence: {confidence:.2f}%", 
         fontsize=10, color='white', 
         bbox=dict(facecolor='black', alpha=0.6))
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step

# %%
def extract_main_region_from_heatmap(heatmap, threshold=0.5, padding_ratio=0.2):
    
    # Create binary mask
    mask = heatmap >= threshold
    
   
    if not np.any(mask):
        threshold = 0.3 * np.max(heatmap)  
        mask = heatmap >= threshold
    
    if not np.any(mask):
        return None
    
    # Find initial coordinates
    coords = np.argwhere(mask)
    y_min, x_min = coords.min(axis=0)
    y_max, x_max = coords.max(axis=0) + 1
    
    # Calculate proportional padding
    height = y_max - y_min
    width = x_max - x_min
    
    # Add padding (20% of region size by default)
    y_pad = int(height * padding_ratio)
    x_pad = int(width * padding_ratio)
    
    # Apply padding with image boundary checks
    y_min = max(0, y_min - y_pad)
    y_max = min(heatmap.shape[0], y_max + y_pad)
    x_min = max(0, x_min - x_pad)
    x_max = min(heatmap.shape[1], x_max + x_pad)
    
    return (y_min, x_min, y_max, x_max)

# Usage with adjusted parameters
bbox = extract_main_region_from_heatmap(
    heatmap, 
    threshold=0.5,
    padding_ratio=.25  # 20% padding around the region
)

if bbox is None:
    print("No activated region found.")
else:
    print("Adjusted Bounding Box:", bbox)
    
    # Crop with padding
    cropped_img = img.crop((bbox[1], bbox[0], bbox[3], bbox[2]))
    
    # Display
    plt.figure(figsize=(6, 6))
    plt.imshow(cropped_img)
    plt.title("Cropped Main Region of CNV")
    plt.axis("off")
    plt.show()
# Out:
# Adjusted Bounding Box: (5, 5, 149, 182)

# %% [markdown]
# **Patch in the region**

# %%
# Convert original image array back to uint8 for visualization
original_image = (img_array[0] * 255).astype(np.uint8)

# Make a copy of the original image to modify
patched_img = original_image.copy()

# Define patch properties
patch_size = 25  # Adjust as needed
x, y = 90, 50  # Change patch location
patch = np.zeros((patch_size, patch_size, 3), dtype=np.uint8)  # Black patch

# Apply the patch
patched_img[y:y+patch_size, x:x+patch_size] = patch

# Preprocess patched image for model (normalize)
patched_img_array = patched_img / 255.0
patched_img_array = np.expand_dims(patched_img_array, axis=0)

# Display original and patched images side by side
plt.figure(figsize=(10, 5))

# Original Image
plt.subplot(1, 2, 1)
plt.imshow(original_image)
plt.title("Original Image")
plt.axis("off")

# Patched Image
plt.subplot(1, 2, 2)
plt.imshow(patched_img)
plt.title("Patched Image")
plt.axis("off")

plt.show()

# %%
# Predict patched image
patched_preds = ensemble_model.predict(patched_img_array)
patched_predicted_class = np.argmax(patched_preds[0])
patched_predicted_label = class_labels[patched_predicted_class]
patched_confidence = np.max(patched_preds[0]) * 100

# Compute Grad-CAM for patched image
patched_heatmap = compute_gradcam(ensemble_model, patched_img_array, target_class_idx=patched_predicted_class, last_conv_layer_name="conv5_block16_concat")

# Display Grad-CAM
plt.figure(figsize=(6, 6))
plt.imshow(patched_img)
plt.imshow(patched_heatmap, cmap='jet', alpha=0.4)
plt.title(f"Grad-CAM for Patched Image\nPredicted: {patched_predicted_label} ({patched_confidence:.2f}%)", fontsize=12, fontweight='bold', color='black')
plt.axis("off")

# Show confidence score inside the image
plt.text(10, 20, f"Confidence: {patched_confidence:.2f}%", fontsize=14, color='white', bbox=dict(facecolor='black', alpha=0.6))

plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step

# %% [markdown]
# **Patch out of the region**

# %%
# Convert original image array back to uint8 for visualization
original_image = (img_array[0] * 255).astype(np.uint8)

# Make a copy of the original image to modify
patched_img = original_image.copy()

# Define patch properties
patch_size = 25  # Adjust as needed
x, y = 180, 60  # Change patch location
patch = np.zeros((patch_size, patch_size, 3), dtype=np.uint8)  # Black patch

# Apply the patch
patched_img[y:y+patch_size, x:x+patch_size] = patch

# Preprocess patched image for model (normalize)
patched_img_array = patched_img / 255.0
patched_img_array = np.expand_dims(patched_img_array, axis=0)

# Display original and patched images side by side
plt.figure(figsize=(10, 5))

# Original Image
plt.subplot(1, 2, 1)
plt.imshow(original_image)
plt.title("Original Image")
plt.axis("off")

# Patched Image
plt.subplot(1, 2, 2)
plt.imshow(patched_img)
plt.title("Patched Image")
plt.axis("off")

plt.show()

# %%
# Predict patched image
patched_preds = ensemble_model.predict(patched_img_array)
patched_predicted_class = np.argmax(patched_preds[0])
patched_predicted_label = class_labels[patched_predicted_class]
patched_confidence = np.max(patched_preds[0]) * 100

# Compute Grad-CAM for patched image
patched_heatmap = compute_gradcam(ensemble_model, patched_img_array, target_class_idx=patched_predicted_class, last_conv_layer_name="conv5_block16_concat")

# Display Grad-CAM
plt.figure(figsize=(6, 6))
plt.imshow(patched_img)
plt.imshow(patched_heatmap, cmap='jet', alpha=0.4)
plt.title(f"Grad-CAM for Patched Image\nPredicted: {patched_predicted_label} ({patched_confidence:.2f}%)", fontsize=12, fontweight='bold', color='black')
plt.axis("off")

# Show confidence score inside the image
plt.text(10, 20, f"Confidence: {patched_confidence:.2f}%", fontsize=14, color='white', bbox=dict(facecolor='black', alpha=0.6))

plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step

# %% [markdown]
# # ->DME

# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

def compute_gradcam(model, img_array, target_class_idx, 
                    backbone_model_name="densenet_wrapper", 
                    last_conv_layer_name="conv5_block16_concat"):

    # Access the backbone model (DenseNet) inside the ensemble
    backbone_model = model.get_layer(backbone_model_name)

    # Create a sub-model for Grad-CAM
    grad_model = tf.keras.models.Model(
        inputs=backbone_model.input,
        outputs=[backbone_model.get_layer(last_conv_layer_name).output, backbone_model.output]
    )
    
    # Forward pass + record gradients
    with tf.GradientTape() as tape:
        conv_outputs, predictions = grad_model(img_array)
        loss = predictions[:, target_class_idx]
    
    # Compute gradients of the output w.r.t. last conv layer
    grads = tape.gradient(loss, conv_outputs)
    weights = tf.reduce_mean(grads, axis=(0, 1, 2))
    
    # Weighted sum of feature maps
    cam = tf.reduce_sum(tf.multiply(weights, conv_outputs), axis=-1)
    cam = tf.nn.relu(cam)  # ReLU activation
    
    # Normalize CAM
    cam = cam - tf.reduce_min(cam)
    cam = cam / (tf.reduce_max(cam) + 1e-8)
    cam = cam[0].numpy()  # Remove batch dimension
    
    # Resize CAM to input image size
    cam = tf.image.resize(cam[..., tf.newaxis], (img_array.shape[1], img_array.shape[2]))
    cam = tf.squeeze(cam).numpy()
    
    return cam

# --- Load and preprocess your test image ---
img_path = '/kaggle/input/oct-of-retina/RETINA OCT/valid/DME/DME-1083927-8.jpeg'

# Load and preprocess
img = tf.keras.preprocessing.image.load_img(img_path, target_size=(224, 224))
img_array = tf.keras.preprocessing.image.img_to_array(img)
img_array = img_array / 255.0  # Normalize as in training
img_array = np.expand_dims(img_array, axis=0)  # Make batch dimension

# --- Class labels ---
class_labels = {0: 'CNV', 1: 'DME', 2: 'DRUSEN', 3: 'NORMAL'}

# --- Predict using your ENSEMBLE model ---
preds = ensemble_model.predict(img_array)
predicted_class = np.argmax(preds[0])
predicted_label = class_labels[predicted_class]
confidence = np.max(preds[0]) * 100

# --- Compute Grad-CAM from DenseNet part inside the ensemble ---
heatmap = compute_gradcam(ensemble_model, img_array, target_class_idx=predicted_class)

# --- Visualization ---
plt.figure(figsize=(6, 6))
plt.imshow(img)
plt.imshow(heatmap, cmap='jet', alpha=0.4)  # Overlay heatmap
plt.title(f"Grad-CAM\nPredicted: {predicted_label} ({confidence:.2f}%)", 
         fontsize=12, fontweight='bold')
plt.axis('off')
plt.text(10, 20, f"Confidence: {confidence:.2f}%", 
         fontsize=10, color='white', 
         bbox=dict(facecolor='black', alpha=0.6))
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step

# %%
def extract_main_region_from_heatmap(heatmap, threshold=0.5, padding_ratio=0.2):
    
    # Create binary mask
    mask = heatmap >= threshold
    
   
    if not np.any(mask):
        threshold = 0.3 * np.max(heatmap)  
        mask = heatmap >= threshold
    
    if not np.any(mask):
        return None
    
    # Find initial coordinates
    coords = np.argwhere(mask)
    y_min, x_min = coords.min(axis=0)
    y_max, x_max = coords.max(axis=0) + 1
    
    # Calculate proportional padding
    height = y_max - y_min
    width = x_max - x_min
    
    # Add padding (20% of region size by default)
    y_pad = int(height * padding_ratio)
    x_pad = int(width * padding_ratio)
    
    # Apply padding with image boundary checks
    y_min = max(0, y_min - y_pad)
    y_max = min(heatmap.shape[0], y_max + y_pad)
    x_min = max(0, x_min - x_pad)
    x_max = min(heatmap.shape[1], x_max + x_pad)
    
    return (y_min, x_min, y_max, x_max)

# Usage with adjusted parameters
bbox = extract_main_region_from_heatmap(
    heatmap, 
    threshold=0.5,
    padding_ratio=.10  # 20% padding around the region
)

if bbox is None:
    print("No activated region found.")
else:
    print("Adjusted Bounding Box:", bbox)
    
    # Crop with padding
    cropped_img = img.crop((bbox[1], bbox[0], bbox[3], bbox[2]))
    
    # Display
    plt.figure(figsize=(6, 6))
    plt.imshow(cropped_img)
    plt.title("Cropped Main Region of DME")
    plt.axis("off")
    plt.show()
# Out:
# Adjusted Bounding Box: (33, 0, 143, 224)

# %% [markdown]
# **Patch in the region**

# %%
# Convert original image array back to uint8 for visualization
original_image = (img_array[0] * 255).astype(np.uint8)

# Make a copy of the original image to modify
patched_img = original_image.copy()

# Define patch properties
patch_size = 25  # Adjust as needed
x, y = 115, 65  # Change patch location
patch = np.zeros((patch_size, patch_size, 3), dtype=np.uint8)  # Black patch

# Apply the patch
patched_img[y:y+patch_size, x:x+patch_size] = patch

# Preprocess patched image for model (normalize)
patched_img_array = patched_img / 255.0
patched_img_array = np.expand_dims(patched_img_array, axis=0)

# Display original and patched images side by side
plt.figure(figsize=(10, 5))

# Original Image
plt.subplot(1, 2, 1)
plt.imshow(original_image)
plt.title("Original Image")
plt.axis("off")

# Patched Image
plt.subplot(1, 2, 2)
plt.imshow(patched_img)
plt.title("Patched Image")
plt.axis("off")

plt.show()

# %%
# Predict patched image
patched_preds = ensemble_model.predict(patched_img_array)
patched_predicted_class = np.argmax(patched_preds[0])
patched_predicted_label = class_labels[patched_predicted_class]
patched_confidence = np.max(patched_preds[0]) * 100

# Compute Grad-CAM for patched image
patched_heatmap = compute_gradcam(ensemble_model, patched_img_array, target_class_idx=patched_predicted_class, last_conv_layer_name="conv5_block16_concat")

# Display Grad-CAM
plt.figure(figsize=(6, 6))
plt.imshow(patched_img)
plt.imshow(patched_heatmap, cmap='jet', alpha=0.4)
plt.title(f"Grad-CAM for Patched Image\nPredicted: {patched_predicted_label} ({patched_confidence:.2f}%)", fontsize=12, fontweight='bold', color='black')
plt.axis("off")

# Show confidence score inside the image
plt.text(10, 20, f"Confidence: {patched_confidence:.2f}%", fontsize=14, color='white', bbox=dict(facecolor='black', alpha=0.6))

plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step

# %% [markdown]
# **Patch out of the region**

# %%
# Convert original image array back to uint8 for visualization
original_image = (img_array[0] * 255).astype(np.uint8)

# Make a copy of the original image to modify
patched_img = original_image.copy()

# Define patch properties
patch_size = 25  # Adjust as needed
x, y = 10, 40  # Change patch location
patch = np.zeros((patch_size, patch_size, 3), dtype=np.uint8)  # Black patch

# Apply the patch
patched_img[y:y+patch_size, x:x+patch_size] = patch

# Preprocess patched image for model (normalize)
patched_img_array = patched_img / 255.0
patched_img_array = np.expand_dims(patched_img_array, axis=0)

# Display original and patched images side by side
plt.figure(figsize=(10, 5))

# Original Image
plt.subplot(1, 2, 1)
plt.imshow(original_image)
plt.title("Original Image")
plt.axis("off")

# Patched Image
plt.subplot(1, 2, 2)
plt.imshow(patched_img)
plt.title("Patched Image")
plt.axis("off")

plt.show()

# %%
# Predict patched image
patched_preds = ensemble_model.predict(patched_img_array)
patched_predicted_class = np.argmax(patched_preds[0])
patched_predicted_label = class_labels[patched_predicted_class]
patched_confidence = np.max(patched_preds[0]) * 100

# Compute Grad-CAM for patched image
patched_heatmap = compute_gradcam(ensemble_model, patched_img_array, target_class_idx=patched_predicted_class, last_conv_layer_name="conv5_block16_concat")

# Display Grad-CAM
plt.figure(figsize=(6, 6))
plt.imshow(patched_img)
plt.imshow(patched_heatmap, cmap='jet', alpha=0.4)
plt.title(f"Grad-CAM for Patched Image\nPredicted: {patched_predicted_label} ({patched_confidence:.2f}%)", fontsize=12, fontweight='bold', color='black')
plt.axis("off")

# Show confidence score inside the image
plt.text(10, 20, f"Confidence: {patched_confidence:.2f}%", fontsize=14, color='white', bbox=dict(facecolor='black', alpha=0.6))

plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step

# %% [markdown]
# # ->DRUSEN

# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

def compute_gradcam(model, img_array, target_class_idx, 
                    backbone_model_name="densenet_wrapper", 
                    last_conv_layer_name="conv5_block16_concat"):

    # Access the backbone model (DenseNet) inside the ensemble
    backbone_model = model.get_layer(backbone_model_name)

    # Create a sub-model for Grad-CAM
    grad_model = tf.keras.models.Model(
        inputs=backbone_model.input,
        outputs=[backbone_model.get_layer(last_conv_layer_name).output, backbone_model.output]
    )
    
    # Forward pass + record gradients
    with tf.GradientTape() as tape:
        conv_outputs, predictions = grad_model(img_array)
        loss = predictions[:, target_class_idx]
    
    # Compute gradients of the output w.r.t. last conv layer
    grads = tape.gradient(loss, conv_outputs)
    weights = tf.reduce_mean(grads, axis=(0, 1, 2))
    
    # Weighted sum of feature maps
    cam = tf.reduce_sum(tf.multiply(weights, conv_outputs), axis=-1)
    cam = tf.nn.relu(cam)  # ReLU activation
    
    # Normalize CAM
    cam = cam - tf.reduce_min(cam)
    cam = cam / (tf.reduce_max(cam) + 1e-8)
    cam = cam[0].numpy()  # Remove batch dimension
    
    # Resize CAM to input image size
    cam = tf.image.resize(cam[..., tf.newaxis], (img_array.shape[1], img_array.shape[2]))
    cam = tf.squeeze(cam).numpy()
    
    return cam

# --- Load and preprocess your test image ---
img_path = '/kaggle/input/oct-of-retina/RETINA OCT/valid/DRUSEN/DRUSEN-1193485-2.jpeg'

# Load and preprocess
img = tf.keras.preprocessing.image.load_img(img_path, target_size=(224, 224))
img_array = tf.keras.preprocessing.image.img_to_array(img)
img_array = img_array / 255.0  # Normalize as in training
img_array = np.expand_dims(img_array, axis=0)  # Make batch dimension

# --- Class labels ---
class_labels = {0: 'CNV', 1: 'DME', 2: 'DRUSEN', 3: 'NORMAL'}

# --- Predict using your ENSEMBLE model ---
preds = ensemble_model.predict(img_array)
predicted_class = np.argmax(preds[0])
predicted_label = class_labels[predicted_class]
confidence = np.max(preds[0]) * 100

# --- Compute Grad-CAM from DenseNet part inside the ensemble ---
heatmap = compute_gradcam(ensemble_model, img_array, target_class_idx=predicted_class)

# --- Visualization ---
plt.figure(figsize=(6, 6))
plt.imshow(img)
plt.imshow(heatmap, cmap='jet', alpha=0.4)  # Overlay heatmap
plt.title(f"Grad-CAM\nPredicted: {predicted_label} ({confidence:.2f}%)", 
         fontsize=12, fontweight='bold')
plt.axis('off')
plt.text(10, 20, f"Confidence: {confidence:.2f}%", 
         fontsize=10, color='white', 
         bbox=dict(facecolor='black', alpha=0.6))
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step

# %%
def extract_main_region_from_heatmap(heatmap, threshold=0.5, padding_ratio=0.2):
    
    # Create binary mask
    mask = heatmap >= threshold
    
   
    if not np.any(mask):
        threshold = 0.3 * np.max(heatmap)  
        mask = heatmap >= threshold
    
    if not np.any(mask):
        return None
    
    # Find initial coordinates
    coords = np.argwhere(mask)
    y_min, x_min = coords.min(axis=0)
    y_max, x_max = coords.max(axis=0) + 1
    
    # Calculate proportional padding
    height = y_max - y_min
    width = x_max - x_min
    
    # Add padding (20% of region size by default)
    y_pad = int(height * padding_ratio)
    x_pad = int(width * padding_ratio)
    
    # Apply padding with image boundary checks
    y_min = max(0, y_min - y_pad)
    y_max = min(heatmap.shape[0], y_max + y_pad)
    x_min = max(0, x_min - x_pad)
    x_max = min(heatmap.shape[1], x_max + x_pad)
    
    return (y_min, x_min, y_max, x_max)

# Usage with adjusted parameters
bbox = extract_main_region_from_heatmap(
    heatmap, 
    threshold=0.5,
    padding_ratio=.10  # 20% padding around the region
)

if bbox is None:
    print("No activated region found.")
else:
    print("Adjusted Bounding Box:", bbox)
    
    # Crop with padding
    cropped_img = img.crop((bbox[1], bbox[0], bbox[3], bbox[2]))
    
    # Display
    plt.figure(figsize=(6, 6))
    plt.imshow(cropped_img)
    plt.title("Cropped Main Region of DRUSEN")
    plt.axis("off")
    plt.show()
# Out:
# Adjusted Bounding Box: (47, 24, 150, 201)

# %% [markdown]
# **Patch in the region**

# %%
# Convert original image array back to uint8 for visualization
original_image = (img_array[0] * 255).astype(np.uint8)

# Make a copy of the original image to modify
patched_img = original_image.copy()

# Define patch properties
patch_size = 25  # Adjust as needed
x, y = 110, 95  # Change patch location
patch = np.zeros((patch_size, patch_size, 3), dtype=np.uint8)  # Black patch

# Apply the patch
patched_img[y:y+patch_size, x:x+patch_size] = patch

# Preprocess patched image for model (normalize)
patched_img_array = patched_img / 255.0
patched_img_array = np.expand_dims(patched_img_array, axis=0)

# Display original and patched images side by side
plt.figure(figsize=(10, 5))

# Original Image
plt.subplot(1, 2, 1)
plt.imshow(original_image)
plt.title("Original Image")
plt.axis("off")

# Patched Image
plt.subplot(1, 2, 2)
plt.imshow(patched_img)
plt.title("Patched Image")
plt.axis("off")

plt.show()

# %%
# Predict patched image
patched_preds = ensemble_model.predict(patched_img_array)
patched_predicted_class = np.argmax(patched_preds[0])
patched_predicted_label = class_labels[patched_predicted_class]
patched_confidence = np.max(patched_preds[0]) * 100

# Compute Grad-CAM for patched image
patched_heatmap = compute_gradcam(ensemble_model, patched_img_array, target_class_idx=patched_predicted_class, last_conv_layer_name="conv5_block16_concat")

# Display Grad-CAM
plt.figure(figsize=(6, 6))
plt.imshow(patched_img)
plt.imshow(patched_heatmap, cmap='jet', alpha=0.4)
plt.title(f"Grad-CAM for Patched Image\nPredicted: {patched_predicted_label} ({patched_confidence:.2f}%)", fontsize=12, fontweight='bold', color='black')
plt.axis("off")

# Show confidence score inside the image
plt.text(10, 20, f"Confidence: {patched_confidence:.2f}%", fontsize=14, color='white', bbox=dict(facecolor='black', alpha=0.6))

plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step

# %% [markdown]
# **Patch out of the region**

# %%
# Convert original image array back to uint8 for visualization
original_image = (img_array[0] * 255).astype(np.uint8)

# Make a copy of the original image to modify
patched_img = original_image.copy()

# Define patch properties
patch_size = 25  # Adjust as needed
x, y = 190, 60  # Change patch location
patch = np.zeros((patch_size, patch_size, 3), dtype=np.uint8)  # Black patch

# Apply the patch
patched_img[y:y+patch_size, x:x+patch_size] = patch

# Preprocess patched image for model (normalize)
patched_img_array = patched_img / 255.0
patched_img_array = np.expand_dims(patched_img_array, axis=0)

# Display original and patched images side by side
plt.figure(figsize=(10, 5))

# Original Image
plt.subplot(1, 2, 1)
plt.imshow(original_image)
plt.title("Original Image")
plt.axis("off")

# Patched Image
plt.subplot(1, 2, 2)
plt.imshow(patched_img)
plt.title("Patched Image")
plt.axis("off")

plt.show()

# %%
# Predict patched image
patched_preds = ensemble_model.predict(patched_img_array)
patched_predicted_class = np.argmax(patched_preds[0])
patched_predicted_label = class_labels[patched_predicted_class]
patched_confidence = np.max(patched_preds[0]) * 100

# Compute Grad-CAM for patched image
patched_heatmap = compute_gradcam(ensemble_model, patched_img_array, target_class_idx=patched_predicted_class, last_conv_layer_name="conv5_block16_concat")

# Display Grad-CAM
plt.figure(figsize=(6, 6))
plt.imshow(patched_img)
plt.imshow(patched_heatmap, cmap='jet', alpha=0.4)
plt.title(f"Grad-CAM for Patched Image\nPredicted: {patched_predicted_label} ({patched_confidence:.2f}%)", fontsize=12, fontweight='bold', color='black')
plt.axis("off")

# Show confidence score inside the image
plt.text(10, 20, f"Confidence: {patched_confidence:.2f}%", fontsize=14, color='white', bbox=dict(facecolor='black', alpha=0.6))

plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step

# %% [markdown]
# # ->NORMAL

# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

def compute_gradcam(model, img_array, target_class_idx, 
                    backbone_model_name="densenet_wrapper", 
                    last_conv_layer_name="conv5_block16_concat"):

    # Access the backbone model (DenseNet) inside the ensemble
    backbone_model = model.get_layer(backbone_model_name)

    # Create a sub-model for Grad-CAM
    grad_model = tf.keras.models.Model(
        inputs=backbone_model.input,
        outputs=[backbone_model.get_layer(last_conv_layer_name).output, backbone_model.output]
    )
    
    # Forward pass + record gradients
    with tf.GradientTape() as tape:
        conv_outputs, predictions = grad_model(img_array)
        loss = predictions[:, target_class_idx]
    
    # Compute gradients of the output w.r.t. last conv layer
    grads = tape.gradient(loss, conv_outputs)
    weights = tf.reduce_mean(grads, axis=(0, 1, 2))
    
    # Weighted sum of feature maps
    cam = tf.reduce_sum(tf.multiply(weights, conv_outputs), axis=-1)
    cam = tf.nn.relu(cam)  # ReLU activation
    
    # Normalize CAM
    cam = cam - tf.reduce_min(cam)
    cam = cam / (tf.reduce_max(cam) + 1e-8)
    cam = cam[0].numpy()  # Remove batch dimension
    
    # Resize CAM to input image size
    cam = tf.image.resize(cam[..., tf.newaxis], (img_array.shape[1], img_array.shape[2]))
    cam = tf.squeeze(cam).numpy()
    
    return cam

# --- Load and preprocess your test image ---
img_path = '/kaggle/input/oct-of-retina/RETINA OCT/valid/NORMAL/NORMAL-1014715-10.jpeg'

# Load and preprocess
img = tf.keras.preprocessing.image.load_img(img_path, target_size=(224, 224))
img_array = tf.keras.preprocessing.image.img_to_array(img)
img_array = img_array / 255.0  # Normalize as in training
img_array = np.expand_dims(img_array, axis=0)  # Make batch dimension

# --- Class labels ---
class_labels = {0: 'CNV', 1: 'DME', 2: 'DRUSEN', 3: 'NORMAL'}

# --- Predict using your ENSEMBLE model ---
preds = ensemble_model.predict(img_array)
predicted_class = np.argmax(preds[0])
predicted_label = class_labels[predicted_class]
confidence = np.max(preds[0]) * 100

# --- Compute Grad-CAM from DenseNet part inside the ensemble ---
heatmap = compute_gradcam(ensemble_model, img_array, target_class_idx=predicted_class)

# --- Visualization ---
plt.figure(figsize=(6, 6))
plt.imshow(img)
plt.imshow(heatmap, cmap='jet', alpha=0.4)  # Overlay heatmap
plt.title(f"Grad-CAM\nPredicted: {predicted_label} ({confidence:.2f}%)", 
         fontsize=12, fontweight='bold')
plt.axis('off')
plt.text(10, 20, f"Confidence: {confidence:.2f}%", 
         fontsize=10, color='white', 
         bbox=dict(facecolor='black', alpha=0.6))
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step

# %%
def extract_main_region_from_heatmap(heatmap, threshold=0.5, padding_ratio=0.2):
    
    # Create binary mask
    mask = heatmap >= threshold
    
   
    if not np.any(mask):
        threshold = 0.3 * np.max(heatmap)  
        mask = heatmap >= threshold
    
    if not np.any(mask):
        return None
    
    # Find initial coordinates
    coords = np.argwhere(mask)
    y_min, x_min = coords.min(axis=0)
    y_max, x_max = coords.max(axis=0) + 1
    
    # Calculate proportional padding
    height = y_max - y_min
    width = x_max - x_min
    
    # Add padding (20% of region size by default)
    y_pad = int(height * padding_ratio)
    x_pad = int(width * padding_ratio)
    
    # Apply padding with image boundary checks
    y_min = max(0, y_min - y_pad)
    y_max = min(heatmap.shape[0], y_max + y_pad)
    x_min = max(0, x_min - x_pad)
    x_max = min(heatmap.shape[1], x_max + x_pad)
    
    return (y_min, x_min, y_max, x_max)

# Usage with adjusted parameters
bbox = extract_main_region_from_heatmap(
    heatmap, 
    threshold=0.5,
    padding_ratio=.20  # 20% padding around the region
)

if bbox is None:
    print("No activated region found.")
else:
    print("Adjusted Bounding Box:", bbox)
    
    # Crop with padding
    cropped_img = img.crop((bbox[1], bbox[0], bbox[3], bbox[2]))
    
    # Display
    plt.figure(figsize=(6, 6))
    plt.imshow(cropped_img)
    plt.title("Cropped Main Region of NORMAL")
    plt.axis("off")
    plt.show()
# Out:
# Adjusted Bounding Box: (8, 0, 137, 224)

# %% [markdown]
# **Patch in the region**

# %%
# Convert original image array back to uint8 for visualization
original_image = (img_array[0] * 255).astype(np.uint8)

# Make a copy of the original image to modify
patched_img = original_image.copy()

# Define patch properties
patch_size = 25  # Adjust as needed
x, y = 100, 60  # Change patch location
patch = np.zeros((patch_size, patch_size, 3), dtype=np.uint8)  # Black patch

# Apply the patch
patched_img[y:y+patch_size, x:x+patch_size] = patch

# Preprocess patched image for model (normalize)
patched_img_array = patched_img / 255.0
patched_img_array = np.expand_dims(patched_img_array, axis=0)

# Display original and patched images side by side
plt.figure(figsize=(10, 5))

# Original Image
plt.subplot(1, 2, 1)
plt.imshow(original_image)
plt.title("Original Image")
plt.axis("off")

# Patched Image
plt.subplot(1, 2, 2)
plt.imshow(patched_img)
plt.title("Patched Image")
plt.axis("off")

plt.show()

# %%
# Predict patched image
patched_preds = ensemble_model.predict(patched_img_array)
patched_predicted_class = np.argmax(patched_preds[0])
patched_predicted_label = class_labels[patched_predicted_class]
patched_confidence = np.max(patched_preds[0]) * 100

# Compute Grad-CAM for patched image
patched_heatmap = compute_gradcam(ensemble_model, patched_img_array, target_class_idx=patched_predicted_class, last_conv_layer_name="conv5_block16_concat")

# Display Grad-CAM
plt.figure(figsize=(6, 6))
plt.imshow(patched_img)
plt.imshow(patched_heatmap, cmap='jet', alpha=0.4)
plt.title(f"Grad-CAM for Patched Image\nPredicted: {patched_predicted_label} ({patched_confidence:.2f}%)", fontsize=12, fontweight='bold', color='black')
plt.axis("off")

# Show confidence score inside the image
plt.text(10, 20, f"Confidence: {patched_confidence:.2f}%", fontsize=14, color='white', bbox=dict(facecolor='black', alpha=0.6))

plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step

# %% [markdown]
# **Patch out of the region**

# %%
# Convert original image array back to uint8 for visualization
original_image = (img_array[0] * 255).astype(np.uint8)

# Make a copy of the original image to modify
patched_img = original_image.copy()

# Define patch properties
patch_size = 25  # Adjust as needed
x, y = 197, 40  # Change patch location
patch = np.zeros((patch_size, patch_size, 3), dtype=np.uint8)  # Black patch

# Apply the patch
patched_img[y:y+patch_size, x:x+patch_size] = patch

# Preprocess patched image for model (normalize)
patched_img_array = patched_img / 255.0
patched_img_array = np.expand_dims(patched_img_array, axis=0)

# Display original and patched images side by side
plt.figure(figsize=(10, 5))

# Original Image
plt.subplot(1, 2, 1)
plt.imshow(original_image)
plt.title("Original Image")
plt.axis("off")

# Patched Image
plt.subplot(1, 2, 2)
plt.imshow(patched_img)
plt.title("Patched Image")
plt.axis("off")

plt.show()

# %%
# Predict patched image
patched_preds = ensemble_model.predict(patched_img_array)
patched_predicted_class = np.argmax(patched_preds[0])
patched_predicted_label = class_labels[patched_predicted_class]
patched_confidence = np.max(patched_preds[0]) * 100

# Compute Grad-CAM for patched image
patched_heatmap = compute_gradcam(ensemble_model, patched_img_array, target_class_idx=patched_predicted_class, last_conv_layer_name="conv5_block16_concat")

# Display Grad-CAM
plt.figure(figsize=(6, 6))
plt.imshow(patched_img)
plt.imshow(patched_heatmap, cmap='jet', alpha=0.4)
plt.title(f"Grad-CAM for Patched Image\nPredicted: {patched_predicted_label} ({patched_confidence:.2f}%)", fontsize=12, fontweight='bold', color='black')
plt.axis("off")

# Show confidence score inside the image
plt.text(10, 20, f"Confidence: {patched_confidence:.2f}%", fontsize=14, color='white', bbox=dict(facecolor='black', alpha=0.6))

plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
